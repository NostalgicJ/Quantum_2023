# %%
import os
import matplotlib.pyplot as plt

# 그림을 저장할 위치
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "v1"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("그림 저장:", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Embedding, RepeatVector, Concatenate, TimeDistributed
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import plot_model


# CSV 파일에서 데이터 읽기
df = pd.read_csv('NVspinData_None_-1_230807.csv')

# 데이터셋 분리 - train_set(train+validation) 8 : test_set 2
train_set, test_set = train_test_split(df, shuffle=True, test_size=0.2)

# df.info()
# train_set.info()
# test_set.info()
# train_set.head()
# test_set.head()
# df.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.3)

# train_set 데이터 전처리 (train+validation)
theta_tv = train_set['Theta'].values.reshape(-1, 1)
phi_tv = train_set['Phi'].values.reshape(-1, 1)
sequence_tv = train_set['combination'].apply(eval).to_list()
max_seq_length_tv = max(len(seq) for seq in sequence_tv)
sequence_padded_tv = pad_sequences(sequence_tv, maxlen=max_seq_length_tv)

# test_set 데이터 전처리 (final_test)
theta_test = test_set['Theta'].values.reshape(-1, 1)
phi_test = test_set['Phi'].values.reshape(-1, 1)
sequence_test = test_set['combination'].apply(eval).to_list()
max_seq_length_test = max(len(seq) for seq in sequence_test)
sequence_padded_test = pad_sequences(sequence_test, maxlen=max_seq_length_test)

# %%
# 모델 구성
# Input : 입력 텐서 반환
theta_input = Input(shape=(1,), name='theta_input')
phi_input = Input(shape=(1,), name='phi_input')
sequence_input = Input(shape=(max_seq_length_tv,), name='sequence_input')

# RepeatVector : sequence와 동일한 길이로 확장
# 각 시퀀스의 모든 단계(원소 스텝 = 타임 스텝)에서 동일한 theta와 phi 값 반복 사용
theta_repeated = RepeatVector(max_seq_length_tv, name='theta_repeated')(theta_input)
phi_repeated = RepeatVector(max_seq_length_tv, name='phi_repeated')(phi_input)
# Embedding : 시퀀스 내의 각 숫자(최대 정수 값 +1 = 5)를 32차원 벡터로 변환
sequence_embedding = Embedding(5, 32, input_length=max_seq_length_tv, name='sequence_embedding')(sequence_input)

# Concatenate : 입력을 연결, 여러 입력 정보 합침
# 입력 레이어 - Input들 합침
concat_layer = Concatenate(name='concat_layer')([theta_repeated, phi_repeated, sequence_embedding])
# RNN 레이어 1
rnn_layer = SimpleRNN(32, return_sequences=True, name='rnn_layer1')(concat_layer)
# RNN 레이어 2
rnn_layer2 = SimpleRNN(64, return_sequences=True, name='rnn_layer2')(rnn_layer)
# RNN 레이어 3
rnn_layer3 = SimpleRNN(128, return_sequences=True, name='rnn_layer3')(rnn_layer2)
# RNN 레이어 4
rnn_layer4 = SimpleRNN(128, return_sequences=True, name='rnn_layer4')(rnn_layer3)
# RNN 레이어 5
rnn_layer5 = SimpleRNN(128, return_sequences=True, name='rnn_layer5')(rnn_layer4)
# RNN 레이어 6
rnn_layer6 = SimpleRNN(128, return_sequences=True, name='rnn_layer6')(rnn_layer5)
# TimeDistributed : Dense 레이어를 각 시간 단계에 독립적으로 적용, 시퀀스의 각 시간 단계에서 동일한 Dense 레이어가 적용
# ... 시퀀스의 각 시간 단계를 독립적으로 예측 가능
# Dense : 출력 뉴런 5개(= 출력 공간 차원), softmax 활성화 함수 사용하는 Dense layer
# 출력 레이어
output = TimeDistributed(Dense(5, activation='softmax'), name='output_layer')(rnn_layer6)

# rnn_layer = SimpleRNN(32, return_sequences=True, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01))(concat_layer)
# rnn_layer2 = SimpleRNN(64, return_sequences=True, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01))(rnn_layer)
# dropout_layer = Dropout(0.5)(rnn_layer2)
# output = TimeDistributed(Dense(5, activation='softmax'))(dropout_layer)

my_model = Model(inputs=[theta_input, phi_input, sequence_input], outputs=output)
print(my_model.summary())
plot_model(my_model, show_shapes=True)

# Compiler        
optimizer = Adam(learning_rate=0.00001)
# optimizer = RMSprop()
my_model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# 데이터셋 분리 train_set 8 : validation_set 2
sequence_train, sequence_val, theta_train, theta_val, phi_train, phi_val = train_test_split(sequence_padded_tv, theta_tv, phi_tv, test_size=0.2)

history = my_model.fit(
    {'theta_input': theta_train, 'phi_input': phi_train, 'sequence_input': sequence_train},
    np.expand_dims(sequence_train, -1), 
    validation_data=({'theta_input': theta_val, 'phi_input': phi_val, 
                        'sequence_input': sequence_val}, np.expand_dims(sequence_val, -1)), epochs=70, batch_size=16)
                        # callbacks=[LearningRateScheduler(lr_schedule)]
# batch 16개로 나누어 70 epoch 만큼 반복
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  theta_input (InputLayer)    [(None, 1)]                  0         []
#
#  phi_input (InputLayer)      [(None, 1)]                  0         []
#
#  sequence_input (InputLayer  [(None, 35)]                 0         []
#  )
#
#  theta_repeated (RepeatVect  (None, 35, 1)                0         ['theta_input[0][0]']
#  or)
#
#  phi_repeated (RepeatVector  (None, 35, 1)                0         ['phi_input[0][0]']
#  )
#
#  sequence_embedding (Embedd  (None, 35, 32)               160       ['sequence_input[0][0]']
#  ing)
#
#  concat_layer (Concatenate)  (None, 35, 34)               0         ['theta_repeated[0][0]',
#                                                                      'phi_repeated[0][0]',
#                                                                      'sequence_embedding[0][0]']
#
#  rnn_layer1 (SimpleRNN)      (None, 35, 32)               2144      ['concat_layer[0][0]']
#
#  rnn_layer2 (SimpleRNN)      (None, 35, 64)               6208      ['rnn_layer1[0][0]']
#
#  rnn_layer3 (SimpleRNN)      (None, 35, 128)              24704     ['rnn_layer2[0][0]']
#
#  rnn_layer4 (SimpleRNN)      (None, 35, 128)              32896     ['rnn_layer3[0][0]']
#
#  rnn_layer5 (SimpleRNN)      (None, 35, 128)              32896     ['rnn_layer4[0][0]']
#
#  rnn_layer6 (SimpleRNN)      (None, 35, 128)              32896     ['rnn_layer5[0][0]']
#
#  output_layer (TimeDistribu  (None, 35, 5)                645       ['rnn_layer6[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 132549 (517.77 KB)
# Trainable params: 132549 (517.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None
# Epoch 1/70
# 494/494 [==============================] - 17s 28ms/step - loss: 1.1144 - accuracy: 0.5551 - val_loss: 0.8500 - val_accuracy: 0.6982
# Epoch 2/70
# 494/494 [==============================] - 13s 27ms/step - loss: 0.6450 - accuracy: 0.7969 - val_loss: 0.4684 - val_accuracy: 0.8586
# Epoch 3/70
# 494/494 [==============================] - 15s 30ms/step - loss: 0.4200 - accuracy: 0.8735 - val_loss: 0.3795 - val_accuracy: 0.8841
# Epoch 4/70
# 494/494 [==============================] - 15s 31ms/step - loss: 0.3572 - accuracy: 0.8931 - val_loss: 0.3320 - val_accuracy: 0.8994
# Epoch 5/70
# 494/494 [==============================] - 15s 31ms/step - loss: 0.3194 - accuracy: 0.9042 - val_loss: 0.2993 - val_accuracy: 0.9095
# Epoch 6/70
# 494/494 [==============================] - 15s 31ms/step - loss: 0.2896 - accuracy: 0.9137 - val_loss: 0.2749 - val_accuracy: 0.9150
# Epoch 7/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.2649 - accuracy: 0.9211 - val_loss: 0.2515 - val_accuracy: 0.9246
# Epoch 8/70
# 494/494 [==============================] - 16s 31ms/step - loss: 0.2456 - accuracy: 0.9257 - val_loss: 0.2371 - val_accuracy: 0.9282
# Epoch 9/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.2299 - accuracy: 0.9298 - val_loss: 0.2214 - val_accuracy: 0.9333
# Epoch 10/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.2175 - accuracy: 0.9326 - val_loss: 0.2112 - val_accuracy: 0.9340
# Epoch 11/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.2068 - accuracy: 0.9346 - val_loss: 0.1996 - val_accuracy: 0.9372
# Epoch 12/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.1975 - accuracy: 0.9368 - val_loss: 0.1924 - val_accuracy: 0.9380
# Epoch 13/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.1896 - accuracy: 0.9384 - val_loss: 0.1834 - val_accuracy: 0.9415
# Epoch 14/70
# 494/494 [==============================] - 17s 34ms/step - loss: 0.1817 - accuracy: 0.9407 - val_loss: 0.1766 - val_accuracy: 0.9428
# Epoch 15/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.1751 - accuracy: 0.9421 - val_loss: 0.1704 - val_accuracy: 0.9445
# Epoch 16/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.1689 - accuracy: 0.9438 - val_loss: 0.1648 - val_accuracy: 0.9470
# Epoch 17/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.1629 - accuracy: 0.9452 - val_loss: 0.1624 - val_accuracy: 0.9454
# Epoch 18/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.1581 - accuracy: 0.9465 - val_loss: 0.1541 - val_accuracy: 0.9491
# Epoch 19/70
# 494/494 [==============================] - 17s 34ms/step - loss: 0.1516 - accuracy: 0.9480 - val_loss: 0.1487 - val_accuracy: 0.9499
# Epoch 20/70
# 494/494 [==============================] - 17s 34ms/step - loss: 0.1468 - accuracy: 0.9495 - val_loss: 0.1444 - val_accuracy: 0.9498
# Epoch 21/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.1421 - accuracy: 0.9505 - val_loss: 0.1388 - val_accuracy: 0.9519
# Epoch 22/70
# 494/494 [==============================] - 15s 29ms/step - loss: 0.1372 - accuracy: 0.9520 - val_loss: 0.1341 - val_accuracy: 0.9539
# Epoch 23/70
# 494/494 [==============================] - 15s 30ms/step - loss: 0.1325 - accuracy: 0.9535 - val_loss: 0.1293 - val_accuracy: 0.9547
# Epoch 24/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.1280 - accuracy: 0.9551 - val_loss: 0.1247 - val_accuracy: 0.9559
# Epoch 25/70
# 494/494 [==============================] - 17s 33ms/step - loss: 0.1232 - accuracy: 0.9563 - val_loss: 0.1213 - val_accuracy: 0.9590
# Epoch 26/70
# 494/494 [==============================] - 18s 36ms/step - loss: 0.1187 - accuracy: 0.9581 - val_loss: 0.1146 - val_accuracy: 0.9594
# Epoch 27/70
# 494/494 [==============================] - 18s 36ms/step - loss: 0.1131 - accuracy: 0.9604 - val_loss: 0.1101 - val_accuracy: 0.9620
# Epoch 28/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.1082 - accuracy: 0.9621 - val_loss: 0.1057 - val_accuracy: 0.9625
# Epoch 29/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.1031 - accuracy: 0.9641 - val_loss: 0.1003 - val_accuracy: 0.9655
# Epoch 30/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0976 - accuracy: 0.9663 - val_loss: 0.0948 - val_accuracy: 0.9688
# Epoch 31/70
# 494/494 [==============================] - 15s 31ms/step - loss: 0.0918 - accuracy: 0.9684 - val_loss: 0.0887 - val_accuracy: 0.9690
# Epoch 32/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.0862 - accuracy: 0.9705 - val_loss: 0.0850 - val_accuracy: 0.9732
# Epoch 33/70
# 494/494 [==============================] - 17s 35ms/step - loss: 0.0801 - accuracy: 0.9731 - val_loss: 0.0771 - val_accuracy: 0.9728
# Epoch 34/70
# 494/494 [==============================] - 17s 35ms/step - loss: 0.0740 - accuracy: 0.9758 - val_loss: 0.0716 - val_accuracy: 0.9790
# Epoch 35/70
# 494/494 [==============================] - 17s 34ms/step - loss: 0.0676 - accuracy: 0.9787 - val_loss: 0.0641 - val_accuracy: 0.9789
# Epoch 36/70
# 494/494 [==============================] - 17s 35ms/step - loss: 0.0612 - accuracy: 0.9814 - val_loss: 0.0577 - val_accuracy: 0.9825
# Epoch 37/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.0548 - accuracy: 0.9844 - val_loss: 0.0521 - val_accuracy: 0.9862
# Epoch 38/70
# 494/494 [==============================] - 17s 35ms/step - loss: 0.0486 - accuracy: 0.9871 - val_loss: 0.0452 - val_accuracy: 0.9873
# Epoch 39/70
# 494/494 [==============================] - 17s 34ms/step - loss: 0.0421 - accuracy: 0.9897 - val_loss: 0.0395 - val_accuracy: 0.9894
# Epoch 40/70
# 494/494 [==============================] - 17s 35ms/step - loss: 0.0361 - accuracy: 0.9919 - val_loss: 0.0333 - val_accuracy: 0.9933
# Epoch 41/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.0305 - accuracy: 0.9940 - val_loss: 0.0283 - val_accuracy: 0.9952
# Epoch 42/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.0255 - accuracy: 0.9956 - val_loss: 0.0234 - val_accuracy: 0.9960
# Epoch 43/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0210 - accuracy: 0.9969 - val_loss: 0.0191 - val_accuracy: 0.9973
# Epoch 44/70
# 494/494 [==============================] - 17s 35ms/step - loss: 0.0170 - accuracy: 0.9980 - val_loss: 0.0156 - val_accuracy: 0.9978
# Epoch 45/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0138 - accuracy: 0.9986 - val_loss: 0.0127 - val_accuracy: 0.9987
# Epoch 46/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.0111 - accuracy: 0.9991 - val_loss: 0.0101 - val_accuracy: 0.9992
# Epoch 47/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0088 - accuracy: 0.9995 - val_loss: 0.0082 - val_accuracy: 0.9996
# Epoch 48/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 0.0066 - val_accuracy: 0.9997
# Epoch 49/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0055 - accuracy: 0.9998 - val_loss: 0.0053 - val_accuracy: 0.9997
# Epoch 50/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0044 - accuracy: 0.9999 - val_loss: 0.0041 - val_accuracy: 0.9998
# Epoch 51/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.0034 - accuracy: 0.9999 - val_loss: 0.0033 - val_accuracy: 0.9999
# Epoch 52/70
# 494/494 [==============================] - 16s 33ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9999
# Epoch 53/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 0.9999
# Epoch 54/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 0.9999
# Epoch 55/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 0.9999
# Epoch 56/70
# 494/494 [==============================] - 16s 32ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 0.9999
# Epoch 57/70
# 494/494 [==============================] - 16s 32ms/step - loss: 7.8376e-04 - accuracy: 1.0000 - val_loss: 8.6427e-04 - val_accuracy: 0.9999
# Epoch 58/70
# 494/494 [==============================] - 16s 32ms/step - loss: 6.1558e-04 - accuracy: 1.0000 - val_loss: 6.9413e-04 - val_accuracy: 0.9999
# Epoch 59/70
# 494/494 [==============================] - 16s 33ms/step - loss: 4.7970e-04 - accuracy: 1.0000 - val_loss: 5.5805e-04 - val_accuracy: 0.9999
# Epoch 60/70
# 494/494 [==============================] - 16s 32ms/step - loss: 3.7524e-04 - accuracy: 1.0000 - val_loss: 4.7329e-04 - val_accuracy: 1.0000
# Epoch 61/70
# 494/494 [==============================] - 16s 32ms/step - loss: 2.9432e-04 - accuracy: 1.0000 - val_loss: 3.7231e-04 - val_accuracy: 1.0000
# Epoch 62/70
# 494/494 [==============================] - 16s 32ms/step - loss: 2.2885e-04 - accuracy: 1.0000 - val_loss: 3.0689e-04 - val_accuracy: 1.0000
# Epoch 63/70
# 494/494 [==============================] - 16s 32ms/step - loss: 1.7943e-04 - accuracy: 1.0000 - val_loss: 2.5295e-04 - val_accuracy: 1.0000
# Epoch 64/70
# 494/494 [==============================] - 16s 32ms/step - loss: 1.4066e-04 - accuracy: 1.0000 - val_loss: 2.0921e-04 - val_accuracy: 1.0000
# Epoch 65/70
# 494/494 [==============================] - 16s 32ms/step - loss: 1.0959e-04 - accuracy: 1.0000 - val_loss: 1.7429e-04 - val_accuracy: 1.0000
# Epoch 66/70
# 494/494 [==============================] - 16s 32ms/step - loss: 8.5798e-05 - accuracy: 1.0000 - val_loss: 1.5333e-04 - val_accuracy: 1.0000
# Epoch 67/70
# 494/494 [==============================] - 16s 32ms/step - loss: 6.7233e-05 - accuracy: 1.0000 - val_loss: 1.1310e-04 - val_accuracy: 1.0000
# Epoch 68/70
# 494/494 [==============================] - 16s 32ms/step - loss: 5.2516e-05 - accuracy: 1.0000 - val_loss: 9.8380e-05 - val_accuracy: 1.0000
# Epoch 69/70
# 494/494 [==============================] - 16s 32ms/step - loss: 4.1330e-05 - accuracy: 1.0000 - val_loss: 8.0045e-05 - val_accuracy: 1.0000
# Epoch 70/70
# 494/494 [==============================] - 16s 32ms/step - loss: 3.2360e-05 - accuracy: 1.0000 - val_loss: 6.3748e-05 - val_accuracy: 1.0000

# %%
# my_model.summary()
# my_model.predict({'theta_input': theta_t, 'phi_input': phi_t, 'sequence_input': seq_t})

def plot_history(history):
         # Plot training & validation loss values
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.axis([45, 70, 0, 0.01])
        plt.legend(['Train', 'Validation'], loc='upper right')
        save_fig("RNN_model_loss")
        plt.show()

        # Plot training & validation accuracy values
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('Model accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.axis([45, 60, 0.999, 1.0])
        plt.legend(['Train', 'Validation'], loc='upper right')
        save_fig("RNN_model_accuracy")
        plt.show()

def evaluate(model, theta, phi, sequence):
    loss, acc = model.evaluate({'theta_input': theta, 'phi_input': phi, 'sequence_input': sequence}, np.expand_dims(sequence, -1))
    print("Test Accuracy: {:.2f}".format(acc*100))
    print("Test Loss: {:.2f}".format(loss*100))

# 결과 그래프 그리기
plot_history(history)

# 모델 성능 평가
evaluate(my_model, theta_test, phi_test, sequence_padded_test)
# Out:
# 그림 저장: RNN_model_loss
# 그림 저장: RNN_model_accuracy
# 78/78 [==============================] - 1s 10ms/step - loss: 3.5500e-05 - accuracy: 1.0000
# Test Accuracy: 100.00
# Test Loss: 0.00

# %%
# 새로운 theta, phi 값에 대한 sequence 예측
new_theta = np.array([[1.03300026]])   # 새로운 theta 값
new_phi = np.array([[5.57917372]])     # 새로운 phi 값
# 'new_sequence'의 길이를 35로 맞추기
new_sequence = np.zeros((1, 35))  # shape (1, 35)의 0으로 이루어진 배열 생성

predicted_sequence = my_model.predict({
    'theta_input': new_theta, 
    'phi_input': new_phi, 
    'sequence_input': new_sequence
})

# 가장 확률이 높은 sequence만 출력
predicted_sequence2 = np.argmax(predicted_sequence, axis=-1)
print(predicted_sequence2)

# %%
# # 테스트 세트에 대한 리스트 예측
# predicted_sequence = rnn_model.my_predict(0.944681, 3.507593, [1, 3, 3, 2, 2, 4, 1, 1, 3, 0, 4])

# # 첫 10개의 예측된 시퀀스 출력
# for i in range(10):
#     print(f"True sequence: {sequence_test[i]}")
#     print(f"Predicted sequence: {np.argmax(predicted_sequence[i], axis=1)}\n")

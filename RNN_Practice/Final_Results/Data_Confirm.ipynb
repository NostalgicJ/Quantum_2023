# %%
import pandas as pd

# CSV 파일에서 데이터 읽기
# df = pd.read_csv('../../Data/using/dt_2.6/ByAstar_dt_2.6_modified.csv')
# df = pd.read_csv('C:\\Users\\Yeojung\\Downloads\\6_Merged file (2).csv_230830\\Merged file (2).csv')
# df = pd.read_csv('C:\\Users\\Yeojung\\Downloads\\6_Merged file (2).csv_230830\\통합 문서1.csv')
# df = pd.read_csv('../../Data/using/dt_2.6/ByAstar_dt_2.6_more.csv')
df = pd.read_csv('../../Data/using/dt_2.6/ByAstar_dt_2.6_0927.csv')
df.info()
# df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25901 entries, 0 to 25900
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gate length     25901 non-null  int64
#  1   Theta           25901 non-null  float64
#  2   Phi             25901 non-null  float64
#  3   dt              25901 non-null  float64
#  4   combination     25901 non-null  object
#  5   total time      25901 non-null  float64
#  6   computing time  25901 non-null  float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 1.4+ MB

# %%
df.astype({ 'Theta' : 'float', 'Phi' : 'float' })
# Out:
#        gate length     Theta       Phi   dt combination  total time  \
# 0                0  0.000098  2.334113  2.6          []         0.0
# 1                0  0.000450  6.093488  2.6          []         0.0
# 2                0  0.000466  2.599058  2.6          []         0.0
# 3                0  0.000616  1.696876  2.6          []         0.0
# 4                0  0.000902  0.279935  2.6          []         0.0
# ...            ...       ...       ...  ...         ...         ...
# 25896            1  0.288176  5.441348  2.6         [4]         2.6
# 25897            1  0.290031  5.206954  2.6         [4]         2.6
# 25898            1  0.291620  5.201045  2.6         [4]         2.6
# 25899            1  0.293051  5.317975  2.6         [4]         2.6
# 25900            1  0.301191  5.057340  2.6         [4]         2.6
#
#        computing time
# 0            0.001999
# 1            0.015646
# 2            0.000000
# 3            0.000000
# 4            0.002997
# ...               ...
# 25896        0.031605
# 25897        0.023998
# 25898        0.019004
# 25899        0.016213
# 25900        0.015678
#
# [25901 rows x 7 columns]

# %%
import matplotlib as plt

# %matplotlib inline
df.hist(bins=50, figsize=(20,15))

# 히스토그램(주어진 값 범위 수평축, 샘플 수 수직축)
# Out:
# array([[<Axes: title={'center': 'gate length'}>,
#         <Axes: title={'center': 'Theta'}>],
#        [<Axes: title={'center': 'Phi'}>, <Axes: title={'center': 'dt'}>],
#        [<Axes: title={'center': 'total time'}>,
#         <Axes: title={'center': 'computing time'}>]], dtype=object)

# %%
df.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.1)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
df2 = df[df['combination'] == '[-1]']

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gate length     0 non-null      int64
#  1   Theta           0 non-null      float64
#  2   Phi             0 non-null      float64
#  3   dt              0 non-null      float64
#  4   combination     0 non-null      object
#  5   total time      0 non-null      float64
#  6   computing time  0 non-null      float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 0.0+ bytes

# %%
df2.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.5)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
df3 = df[df['combination'] != '[-1]']

df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25901 entries, 0 to 25900
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gate length     25901 non-null  int64
#  1   Theta           25901 non-null  float64
#  2   Phi             25901 non-null  float64
#  3   dt              25901 non-null  float64
#  4   combination     25901 non-null  object
#  5   total time      25901 non-null  float64
#  6   computing time  25901 non-null  float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 1.4+ MB

# %%
df3.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.1)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
s = sum(df["computing time"])

m = s / len(df["computing time"])

mi = min(df["computing time"])

ma = max(df["computing time"])

print(s, "/", m, "/", mi, "/", ma)
# Out:
# 10600520.009199267 / 409.2706848847252 / 0.0 / 146206.2217

# %%
import pandas as pd

# CSV 파일에서 데이터 읽기
# df = pd.read_csv('../../Data/using/dt_2.6/ByAstar_dt_2.6_modified.csv')
# df = pd.read_csv('C:\\Users\\Yeojung\\Downloads\\6_Merged file (2).csv_230830\\Merged file (2).csv')
# df = pd.read_csv('C:\\Users\\Yeojung\\Downloads\\6_Merged file (2).csv_230830\\통합 문서1.csv')
df = pd.read_csv('C:\\Users\\Yeojung\\Downloads\\Merged file.csv')
df.info()
# df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842 entries, 0 to 841
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gate length     842 non-null    int64
#  1   Theta           842 non-null    float64
#  2   Phi             842 non-null    float64
#  3   dt              842 non-null    float64
#  4   combination     842 non-null    object
#  5   total time      842 non-null    float64
#  6   computing time  842 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 46.2+ KB

# %%
df.astype({ 'Theta' : 'float', 'Phi' : 'float' })
# Out:
#      gate length     Theta       Phi   dt  \
# 0             10  0.798858  5.669890  2.6
# 1             10  0.879161  5.533088  2.6
# 2              2  0.247483  0.314160  2.6
# 3             33  2.900953  3.895591  2.6
# 4              3  0.482694  3.817210  2.6
# ..           ...       ...       ...  ...
# 837           34  2.769081  0.138089  2.6
# 838           26  2.384539  3.927696  2.6
# 839           19  1.536042  0.147312  2.6
# 840           27  2.502943  3.464703  2.6
# 841           26  2.160030  2.379329  2.6
#
#                                            combination  total time  \
# 0                       [4, 4, 1, 1, 3, 3, 2, 4, 4, 0]        26.0
# 1                       [4, 4, 1, 1, 3, 3, 2, 2, 2, 4]        26.0
# 2                                               [4, 1]         5.2
# 3    [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, ...        85.8
# 4                                            [3, 2, 2]         7.8
# ..                                                 ...         ...
# 837  [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, ...        88.4
# 838  [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, ...        67.6
# 839  [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, ...        49.4
# 840  [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, ...        70.2
# 841  [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, ...        67.6
#
#      computing time
# 0         13.788472
# 1          7.272540
# 2          0.046680
# 3        207.972299
# 4          0.251133
# ..              ...
# 837     1231.186067
# 838       44.002227
# 839      159.753057
# 840       40.302601
# 841      327.727276
#
# [842 rows x 7 columns]

# %%
import matplotlib as plt

# %matplotlib inline
df.hist(bins=50, figsize=(20,15))

# 히스토그램(주어진 값 범위 수평축, 샘플 수 수직축)
# Out:
# array([[<Axes: title={'center': 'gate length'}>,
#         <Axes: title={'center': 'Theta'}>],
#        [<Axes: title={'center': 'Phi'}>, <Axes: title={'center': 'dt'}>],
#        [<Axes: title={'center': 'total time'}>,
#         <Axes: title={'center': 'computing time'}>]], dtype=object)

# %%
df.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.5)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
df2 = df[df['combination'] == '[-1]']

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115 entries, 16 to 829
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gate length     115 non-null    int64
#  1   Theta           115 non-null    float64
#  2   Phi             115 non-null    float64
#  3   dt              115 non-null    float64
#  4   combination     115 non-null    object
#  5   total time      115 non-null    float64
#  6   computing time  115 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df2.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.5)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
import pandas as pd

# CSV 파일에서 데이터 읽기
# df = pd.read_csv('../../Data/using/dt_2.6/ByAstar_dt_2.6_modified.csv')
# df = pd.read_csv('C:\\Users\\Yeojung\\Downloads\\6_Merged file (2).csv_230830\\Merged file (2).csv')
df = pd.read_csv('C:\\Users\\Yeojung\\Downloads\\6_Merged file (2).csv_230830\\통합 문서1.csv')
df.info()
# df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Case            165 non-null    object
#  1   gate length     165 non-null    int64
#  2   Theta           165 non-null    float64
#  3   Phi             165 non-null    float64
#  4   dt              165 non-null    float64
#  5   combination     165 non-null    object
#  6   total time      165 non-null    float64
#  7   computing time  165 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 10.4+ KB

# %%
df.astype({ 'Theta' : 'float', 'Phi' : 'float' })
# Out:
#        Case  gate length     Theta       Phi   dt combination  total time  \
# 0    case17            1  1.797056  2.525361  2.6        [-1]         2.6
# 1    case18            1  2.491550  2.614309  2.6        [-1]         2.6
# 2    case24            1  1.214336  5.231185  2.6        [-1]         2.6
# 3    case25            1  1.963300  1.136951  2.6        [-1]         2.6
# 4    case28            1  1.211177  2.274602  2.6        [-1]         2.6
# ..      ...          ...       ...       ...  ...         ...         ...
# 160  case16            1  1.915384  4.237640  2.6        [-1]         2.6
# 161  case21            1  1.956254  4.786884  2.6        [-1]         2.6
# 162  case27            1  1.190856  1.251043  2.6        [-1]         2.6
# 163  case30            1  1.921220  4.743969  2.6        [-1]         2.6
# 164  case33            1  1.962814  4.776881  2.6        [-1]         2.6
#
#      computing time
# 0       4683.361897
# 1       4316.096053
# 2       4823.649945
# 3       5193.892772
# 4       4762.221124
# ..              ...
# 160     4851.261454
# 161     5309.717253
# 162     5260.745209
# 163     5385.880902
# 164     5475.713985
#
# [165 rows x 8 columns]

# %%
import matplotlib as plt

# %matplotlib inline
df.hist(bins=50, figsize=(20,15))

# 히스토그램(주어진 값 범위 수평축, 샘플 수 수직축)
# Out:
# array([[<Axes: title={'center': 'gate length'}>,
#         <Axes: title={'center': 'Theta'}>],
#        [<Axes: title={'center': 'Phi'}>, <Axes: title={'center': 'dt'}>],
#        [<Axes: title={'center': 'total time'}>,
#         <Axes: title={'center': 'computing time'}>]], dtype=object)

# %%
df.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.5)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

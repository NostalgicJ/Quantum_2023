# %%
import pandas as pd

df1 = pd.read_csv("ByAstar_dt_2.6_0927.csv")
# df2 = pd.read_csv("ByAstar_dt_2.6_20230825_160922.csv")
# df3 = pd.read_csv("ByAstar_dt_2.6_20230825_163313.csv")
# df4 = pd.read_csv("concatenated/server_data_concatenated_20231005_103940.csv")
# df5 = pd.read_csv("ByAstar_dt_2.6_20230904_091658.csv")
# df6 = pd.read_csv("ByAstar_dt_2.6_20230904_102332.csv")
# df7 = pd.read_csv("ByAstar_dt_2.6_20230904_102345.csv")
# df8 = pd.read_csv("ByAstar_dt_2.6_20230904_102436.csv")
# df9 = pd.read_csv("ByAstar_dt_2.6_20230908_180113.csv")
# df10 = pd.read_csv("ByAstar_dt_2.6_20230908_180125.csv")
# df11 = pd.read_csv("ByAstar_dt_2.6_20230908_180131.csv")
# df12 = pd.read_csv("ByAstar_dt_2.6_20230908_180138.csv")
# df13 = pd.read_csv("ByAstar_dt_2.6_20230908_180143.csv")
# df14 = pd.read_csv("ByAstar_dt_2.6_20230911_132804.csv")
# df15 = pd.read_csv("ByAstar_dt_2.6_20230911_132817.csv")
# df16 = pd.read_csv("ByAstar_dt_2.6_20230911_132823.csv")
# df17 = pd.read_csv("ByAstar_dt_2.6_20230911_132831.csv")
# df18 = pd.read_csv("ByAstar_dt_2.6_20230911_132839.csv")

# %%
result = pd.concat([df1,df4])

result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28358 entries, 0 to 2456
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gate length     28358 non-null  int64
#  1   Theta           28358 non-null  float64
#  2   Phi             28358 non-null  float64
#  3   dt              28358 non-null  float64
#  4   combination     28358 non-null  object
#  5   total time      28358 non-null  float64
#  6   computing time  28358 non-null  float64
#  7   Case            2457 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 1.9+ MB

# %%
import matplotlib as plt

# %matplotlib inline

result.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'gate length'}>,
#         <Axes: title={'center': 'Theta'}>],
#        [<Axes: title={'center': 'Phi'}>, <Axes: title={'center': 'dt'}>],
#        [<Axes: title={'center': 'total time'}>,
#         <Axes: title={'center': 'computing time'}>]], dtype=object)

# %%
result.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Yeojung\ml\Quantum_2023\Data\using\dt_2.6\need_preprocessing\concat_files.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Yeojung/ml/Quantum_2023/Data/using/dt_2.6/need_preprocessing/concat_files.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> result.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.2)
#
# NameError: name 'result' is not defined

# %%
result_minus_1 = result[result['combination'] == '[-1]']

result_minus_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gate length     0 non-null      int64
#  1   Theta           0 non-null      float64
#  2   Phi             0 non-null      float64
#  3   dt              0 non-null      float64
#  4   combination     0 non-null      object
#  5   total time      0 non-null      float64
#  6   computing time  0 non-null      float64
#  7   Case            0 non-null      object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 0.0+ bytes

# %%
result_minus_1.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.5)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
result_preprocessed = result[result['combination'] != '[-1]']

result_preprocessed.info()

result_preprocessed.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.2)

# %%
import os
from datetime import datetime

# Create a directory to store the results
dir = 'concatenated'
if not os.path.exists(dir):
    os.makedirs(dir)

# CSV file name setup
date = datetime.now()
printdate = date.strftime('%Y%m%d_%H%M%S')

filename = "/data_concatenated_" + printdate + '.csv'

result_preprocessed.to_csv(dir + filename, index=False)

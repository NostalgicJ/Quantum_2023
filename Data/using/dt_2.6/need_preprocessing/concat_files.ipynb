# %%
import pandas as pd

df1 = pd.read_csv("ByAstar_dt_2.6_part_20230927_143016.csv")
df2 = pd.read_csv("ByAstar_dt_2.6_part_20230927_143347.csv")
df3 = pd.read_csv("ByAstar_dt_2.6_part_20230927_143625.csv")
df4 = pd.read_csv("concatenated/server_data_concatenated_20231005_102417.csv")
# df5 = pd.read_csv("ByAstar_dt_2.6_20230904_091658.csv")
# df6 = pd.read_csv("ByAstar_dt_2.6_20230904_102332.csv")
# df7 = pd.read_csv("ByAstar_dt_2.6_20230904_102345.csv")
# df8 = pd.read_csv("ByAstar_dt_2.6_20230904_102436.csv")
# df9 = pd.read_csv("ByAstar_dt_2.6_20230908_180113.csv")
# df10 = pd.read_csv("ByAstar_dt_2.6_20230908_180125.csv")
# df11 = pd.read_csv("ByAstar_dt_2.6_20230908_180131.csv")
# df12 = pd.read_csv("ByAstar_dt_2.6_20230908_180138.csv")
# df13 = pd.read_csv("ByAstar_dt_2.6_20230908_180143.csv")
# df14 = pd.read_csv("ByAstar_dt_2.6_20230911_132804.csv")
# df15 = pd.read_csv("ByAstar_dt_2.6_20230911_132817.csv")
# df16 = pd.read_csv("ByAstar_dt_2.6_20230911_132823.csv")
# df17 = pd.read_csv("ByAstar_dt_2.6_20230911_132831.csv")
# df18 = pd.read_csv("ByAstar_dt_2.6_20230911_132839.csv")

# %%
result = pd.concat([df1,df2,df3,df4])

result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2494 entries, 0 to 2227
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Case            2494 non-null   object
#  1   gate length     2494 non-null   int64
#  2   Theta           2494 non-null   float64
#  3   Phi             2494 non-null   float64
#  4   dt              2494 non-null   float64
#  5   combination     2494 non-null   object
#  6   total time      2494 non-null   float64
#  7   computing time  2494 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 175.4+ KB

# %%
import matplotlib as plt

# %matplotlib inline

result.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'gate length'}>,
#         <Axes: title={'center': 'Theta'}>],
#        [<Axes: title={'center': 'Phi'}>, <Axes: title={'center': 'dt'}>],
#        [<Axes: title={'center': 'total time'}>,
#         <Axes: title={'center': 'computing time'}>]], dtype=object)

# %%
result.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.5)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
result_minus_1 = result[result['combination'] == '[-1]']

result_minus_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73 entries, 0 to 88
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Case            73 non-null     object
#  1   gate length     73 non-null     int64
#  2   Theta           73 non-null     float64
#  3   Phi             73 non-null     float64
#  4   dt              73 non-null     float64
#  5   combination     73 non-null     object
#  6   total time      73 non-null     float64
#  7   computing time  73 non-null     float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 5.1+ KB

# %%
result_minus_1.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.5)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
result_preprocessed = result[result['combination'] != '[-1]']

result_preprocessed.info()

result_preprocessed.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2421 entries, 1 to 2227
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Case            2421 non-null   object
#  1   gate length     2421 non-null   int64
#  2   Theta           2421 non-null   float64
#  3   Phi             2421 non-null   float64
#  4   dt              2421 non-null   float64
#  5   combination     2421 non-null   object
#  6   total time      2421 non-null   float64
#  7   computing time  2421 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 170.2+ KB
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
import os
from datetime import datetime

# Create a directory to store the results
dir = 'concatenated'
if not os.path.exists(dir):
    os.makedirs(dir)

# CSV file name setup
date = datetime.now()
printdate = date.strftime('%Y%m%d_%H%M%S')

filename = "/server_data_concatenated_" + printdate + '.csv'

result_preprocessed.to_csv(dir + filename, index=False)

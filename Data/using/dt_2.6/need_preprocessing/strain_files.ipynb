# %%
import pandas as pd

df = pd.read_csv("concatenated/data_concatenated_20231016_132031.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30007 entries, 0 to 30006
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gate length     30007 non-null  int64
#  1   Theta           30007 non-null  float64
#  2   Phi             30007 non-null  float64
#  3   dt              30007 non-null  float64
#  4   combination     30007 non-null  object
#  5   total time      30007 non-null  float64
#  6   computing time  30007 non-null  float64
#  7   Case            4106 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 1.8+ MB

# %%
import matplotlib as plt

# %matplotlib inline

df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'gate length'}>,
#         <Axes: title={'center': 'Theta'}>],
#        [<Axes: title={'center': 'Phi'}>, <Axes: title={'center': 'dt'}>],
#        [<Axes: title={'center': 'total time'}>,
#         <Axes: title={'center': 'computing time'}>]], dtype=object)

# %%
df.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.1)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
result_minus_1 = df[df['combination'] == '[-1]']

result_minus_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gate length     0 non-null      int64
#  1   Theta           0 non-null      float64
#  2   Phi             0 non-null      float64
#  3   dt              0 non-null      float64
#  4   combination     0 non-null      object
#  5   total time      0 non-null      float64
#  6   computing time  0 non-null      float64
#  7   Case            0 non-null      object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 0.0+ bytes

# %%
df[df.duplicated(keep=False)]
# Out:
#        gate length     Theta       Phi   dt  \
# 1568            25  2.361343  5.805962  2.6
# 1569            25  2.361343  5.805962  2.6
# 2442            27  2.483421  1.851490  2.6
# 2443            27  2.483421  1.851490  2.6
# 2467            27  2.650313  1.775229  2.6
# ...            ...       ...       ...  ...
# 24458           24  2.364660  4.087645  2.6
# 25707           25  2.359670  4.219165  2.6
# 25708           25  2.359670  4.219165  2.6
# 25709           25  2.363142  4.193494  2.6
# 25710           25  2.363142  4.193494  2.6
#
#                                              combination  total time  \
# 1568   [1, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, ...        65.0
# 1569   [1, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, ...        65.0
# 2442   [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, ...        70.2
# 2443   [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, ...        70.2
# 2467   [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, ...        70.2
# ...

# %%
df = df.drop_duplicates()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29528 entries, 0 to 30006
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gate length     29528 non-null  int64
#  1   Theta           29528 non-null  float64
#  2   Phi             29528 non-null  float64
#  3   dt              29528 non-null  float64
#  4   combination     29528 non-null  object
#  5   total time      29528 non-null  float64
#  6   computing time  29528 non-null  float64
#  7   Case            4106 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 2.0+ MB

# %%
df.plot(kind = "scatter", x="Theta", y="Phi", alpha=0.05)
# Out:
# <Axes: xlabel='Theta', ylabel='Phi'>

# %%
import os
from datetime import datetime

# Create a directory to store the results
dir = 'strained'
if not os.path.exists(dir):
    os.makedirs(dir)

# CSV file name setup
date = datetime.now()
printdate = date.strftime('%Y%m%d_%H%M%S')

filename = "/data_strained_" + printdate + '.csv'

df.to_csv(dir + filename, index=False)

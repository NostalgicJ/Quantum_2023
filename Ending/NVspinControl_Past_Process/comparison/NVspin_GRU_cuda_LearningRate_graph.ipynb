# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense, Concatenate, TimeDistributed, RepeatVector
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# 데이터 불러오기
df = pd.read_csv('../../../Data/using/dt_2.6/ByAstar_dt_2.6_1016.csv')

df = df.dropna(subset=['combination'])

# 데이터셋 분리: train_set 8 : test_set 2
train_df, test_df = train_test_split(df, shuffle=True, test_size=0.2)
# train_set을 다시 8:2로 나눠서 train_set과 validation_set을 만듦
train_df, val_df = train_test_split(train_df, shuffle=True, test_size=0.2)
# random_state=42

# 모든 시퀀스의 길이 중에서 최대 길이를 구하기
all_sequences = [eval(str(seq)) for seq in df['combination'].values]
max_seq_length = max([len(seq) for seq in all_sequences])

# 각 데이터셋에서 theta, phi, sequence 추출하고 reshape 적용
theta_train = train_df['Theta'].values.reshape(-1, 1)
phi_train = train_df['Phi'].values.reshape(-1, 1)
sequence_train = pad_sequences(train_df['combination'].apply(eval).tolist(), maxlen=max_seq_length, padding='pre')

theta_val = val_df['Theta'].values.reshape(-1, 1)
phi_val = val_df['Phi'].values.reshape(-1, 1)
sequence_val = pad_sequences(val_df['combination'].apply(eval).tolist(), maxlen=max_seq_length, padding='pre')

theta_test = test_df['Theta'].values.reshape(-1, 1)
phi_test = test_df['Phi'].values.reshape(-1, 1)
sequence_test = pad_sequences(test_df['combination'].apply(eval).tolist(), maxlen=max_seq_length, padding='pre')

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# 모델 정의
theta_input = Input(shape=(1,), name='theta_input')
phi_input = Input(shape=(1,), name='phi_input')

# theta와 phi를 Concatenate
merged = Concatenate()([theta_input, phi_input])

# 시퀀스를 예측하기 위한 GRU 레이어
repeated_vector = RepeatVector(max_seq_length)(merged)  # max_sequence_length는 시퀀스의 최대 길이

rnn_layer = GRU(256, return_sequences=True, name='rnn_layer')(repeated_vector)

output = TimeDistributed(Dense(5, activation='softmax'), name='output_layer')(rnn_layer)

model = Model(inputs=[theta_input, phi_input], outputs=output)

# 컴파일 및 훈련
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

history = model.fit([theta_train, phi_train], np.expand_dims(sequence_train, -1), 
                    validation_data=([theta_val, phi_val], np.expand_dims(sequence_val, -1)), epochs=500, batch_size=64,
                    callbacks=[early_stopping])

# 검증
loss, accuracy = model.evaluate([theta_test, phi_test], np.expand_dims(sequence_test, -1))
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 2023-11-10 13:36:39.201521: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-10 13:36:39.232619: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-10 13:36:39.232681: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-10 13:36:39.234831: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-10 13:36:39.234881: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-10 13:36:39.234915: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-10 13:36:39.788424: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-10 13:36:39.788514: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-10 13:36:39.788523: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1722] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-11-10 13:36:39.788561: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-10 13:36:39.788588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21192 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-10 13:36:46.049300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-10 13:36:46.050383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-10 13:36:46.051128: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/500
# 2023-11-10 13:36:46.337568: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-10 13:36:46.338837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-10 13:36:46.339959: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-11-10 13:36:46.799404: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-10 13:36:46.800887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-10 13:36:46.802095: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-11-10 13:36:48.222639: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-11-10 13:36:48.339741: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-10 13:36:48.344251: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f2db4ad9910 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-10 13:36:48.344278: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-11-10 13:36:48.347717: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-10 13:36:48.397133: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-11-10 13:36:48.434002: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 296/296 [==============================] - ETA: 0s - loss: 0.9397 - accuracy: 0.5703
# 2023-11-10 13:36:50.871207: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-11-10 13:36:50.872439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-11-10 13:36:50.873603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 296/296 [==============================] - 5s 8ms/step - loss: 0.9397 - accuracy: 0.5703 - val_loss: 0.8579 - val_accuracy: 0.5849
# Epoch 2/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.7397 - accuracy: 0.6657 - val_loss: 0.4356 - val_accuracy: 0.8452
# Epoch 3/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.3897 - accuracy: 0.8576 - val_loss: 0.3640 - val_accuracy: 0.8593
# Epoch 4/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.3424 - accuracy: 0.8723 - val_loss: 0.3185 - val_accuracy: 0.8825
# Epoch 5/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.3129 - accuracy: 0.8814 - val_loss: 0.3104 - val_accuracy: 0.8823
# Epoch 6/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.3094 - accuracy: 0.8817 - val_loss: 0.3013 - val_accuracy: 0.8832
# Epoch 7/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2951 - accuracy: 0.8864 - val_loss: 0.2588 - val_accuracy: 0.9009
# Epoch 8/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2819 - accuracy: 0.8912 - val_loss: 0.2925 - val_accuracy: 0.8837
# Epoch 9/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2874 - accuracy: 0.8881 - val_loss: 0.2964 - val_accuracy: 0.8801
# Epoch 10/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2836 - accuracy: 0.8899 - val_loss: 0.2725 - val_accuracy: 0.8937
# Epoch 11/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2704 - accuracy: 0.8942 - val_loss: 0.2590 - val_accuracy: 0.8970
# Epoch 12/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2698 - accuracy: 0.8941 - val_loss: 0.2564 - val_accuracy: 0.9030
# Epoch 13/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2683 - accuracy: 0.8940 - val_loss: 0.3070 - val_accuracy: 0.8818
# Epoch 14/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2668 - accuracy: 0.8950 - val_loss: 0.2611 - val_accuracy: 0.8966
# Epoch 15/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2607 - accuracy: 0.8976 - val_loss: 0.2606 - val_accuracy: 0.8956
# Epoch 16/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2575 - accuracy: 0.8972 - val_loss: 0.2438 - val_accuracy: 0.9022
# Epoch 17/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2575 - accuracy: 0.8977 - val_loss: 0.2394 - val_accuracy: 0.9062
# Epoch 18/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2546 - accuracy: 0.8985 - val_loss: 0.2389 - val_accuracy: 0.9056
# Epoch 19/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2510 - accuracy: 0.8999 - val_loss: 0.2305 - val_accuracy: 0.9080
# Epoch 20/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2465 - accuracy: 0.9007 - val_loss: 0.2443 - val_accuracy: 0.9013
# Epoch 21/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2471 - accuracy: 0.9003 - val_loss: 0.2622 - val_accuracy: 0.8963
# Epoch 22/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2406 - accuracy: 0.9031 - val_loss: 0.2208 - val_accuracy: 0.9094
# Epoch 23/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2401 - accuracy: 0.9026 - val_loss: 0.2217 - val_accuracy: 0.9105
# Epoch 24/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2394 - accuracy: 0.9029 - val_loss: 0.2360 - val_accuracy: 0.9049
# Epoch 25/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2368 - accuracy: 0.9038 - val_loss: 0.2514 - val_accuracy: 0.9010
# Epoch 26/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2373 - accuracy: 0.9039 - val_loss: 0.2170 - val_accuracy: 0.9113
# Epoch 27/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2363 - accuracy: 0.9032 - val_loss: 0.2408 - val_accuracy: 0.8997
# Epoch 28/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2326 - accuracy: 0.9050 - val_loss: 0.2321 - val_accuracy: 0.9078
# Epoch 29/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2289 - accuracy: 0.9056 - val_loss: 0.2100 - val_accuracy: 0.9131
# Epoch 30/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2252 - accuracy: 0.9073 - val_loss: 0.2287 - val_accuracy: 0.9076
# Epoch 31/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2293 - accuracy: 0.9055 - val_loss: 0.2284 - val_accuracy: 0.9069
# Epoch 32/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2286 - accuracy: 0.9061 - val_loss: 0.2502 - val_accuracy: 0.8982
# Epoch 33/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2244 - accuracy: 0.9074 - val_loss: 0.2206 - val_accuracy: 0.9079
# Epoch 34/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2228 - accuracy: 0.9083 - val_loss: 0.2416 - val_accuracy: 0.8993
# Epoch 35/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2196 - accuracy: 0.9090 - val_loss: 0.2730 - val_accuracy: 0.8914
# Epoch 36/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2207 - accuracy: 0.9082 - val_loss: 0.2197 - val_accuracy: 0.9081
# Epoch 37/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2196 - accuracy: 0.9091 - val_loss: 0.2111 - val_accuracy: 0.9124
# Epoch 38/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2214 - accuracy: 0.9076 - val_loss: 0.2196 - val_accuracy: 0.9097
# Epoch 39/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2205 - accuracy: 0.9090 - val_loss: 0.2211 - val_accuracy: 0.9110
# Epoch 40/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2150 - accuracy: 0.9103 - val_loss: 0.2374 - val_accuracy: 0.9035
# Epoch 41/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2172 - accuracy: 0.9092 - val_loss: 0.2035 - val_accuracy: 0.9153
# Epoch 42/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2159 - accuracy: 0.9094 - val_loss: 0.2076 - val_accuracy: 0.9129
# Epoch 43/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2107 - accuracy: 0.9121 - val_loss: 0.2224 - val_accuracy: 0.9102
# Epoch 44/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2184 - accuracy: 0.9087 - val_loss: 0.1907 - val_accuracy: 0.9201
# Epoch 45/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2142 - accuracy: 0.9112 - val_loss: 0.1959 - val_accuracy: 0.9190
# Epoch 46/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2066 - accuracy: 0.9137 - val_loss: 0.2035 - val_accuracy: 0.9175
# Epoch 47/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2144 - accuracy: 0.9098 - val_loss: 0.2061 - val_accuracy: 0.9127
# Epoch 48/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2154 - accuracy: 0.9104 - val_loss: 0.1942 - val_accuracy: 0.9187
# Epoch 49/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2089 - accuracy: 0.9129 - val_loss: 0.2143 - val_accuracy: 0.9099
# Epoch 50/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2070 - accuracy: 0.9133 - val_loss: 0.2340 - val_accuracy: 0.9031
# Epoch 51/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2063 - accuracy: 0.9129 - val_loss: 0.2136 - val_accuracy: 0.9088
# Epoch 52/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2041 - accuracy: 0.9134 - val_loss: 0.2062 - val_accuracy: 0.9146
# Epoch 53/500
# 296/296 [==============================] - 2s 7ms/step - loss: 0.2053 - accuracy: 0.9138 - val_loss: 0.1913 - val_accuracy: 0.9194
# Epoch 54/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2067 - accuracy: 0.9131 - val_loss: 0.2323 - val_accuracy: 0.9017
# Epoch 55/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2016 - accuracy: 0.9154 - val_loss: 0.2020 - val_accuracy: 0.9170
# Epoch 56/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2020 - accuracy: 0.9155 - val_loss: 0.2029 - val_accuracy: 0.9153
# Epoch 57/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.1999 - accuracy: 0.9159 - val_loss: 0.1995 - val_accuracy: 0.9165
# Epoch 58/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2002 - accuracy: 0.9157 - val_loss: 0.2060 - val_accuracy: 0.9149
# Epoch 59/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0.2007 - accuracy: 0.9156 - val_loss: 0.2079 - val_accuracy: 0.9144
# Epoch 60/500
# 296/296 [==============================] - 2s 7ms/step - loss: 0.2033 - accuracy: 0.9142 - val_loss: 0.2016 - val_accuracy: 0.9164
# Epoch 61/500
# 296/296 [==============================] - 2s 6ms/step - loss: 0
500
# 296/296 [==============================] - 27s 90ms/step - loss: 0.1672 - accuracy: 0.9270 - val_loss: 0.1872 - val_accuracy: 0.9226
# Epoch 167/500
# 296/296 [==============================] - 26s 90ms/step - loss: 0.1683 - accuracy: 0.9259 - val_loss: 0.1742 - val_accuracy: 0.9229
# Epoch 168/500
# 296/296 [==============================] - 26s 89ms/step - loss: 0.1637 - accuracy: 0.9271 - val_loss: 0.1761 - val_accuracy: 0.9245
# Epoch 169/500
# 296/296 [==============================] - 27s 90ms/step - loss: 0.1611 - accuracy: 0.9286 - val_loss: 0.1796 - val_accuracy: 0.9227
# Epoch 170/500
# 296/296 [==============================] - 27s 90ms/step - loss: 0.1648 - accuracy: 0.9275 - val_loss: 0.1672 - val_accuracy: 0.9260
# Epoch 171/500
# 296/296 [==============================] - 26s 89ms/step - loss: 0.1636 - accuracy: 0.9276 - val_loss: 0.1648 - val_accuracy: 0.9277
# Epoch 172/500
# 296/296 [==============================] - 27s 91ms/step - loss: 0.1638 - accuracy: 0.9277 - val_loss: 0.1739 - val_accuracy: 0.9243
# Epoch 173/500
# 296/296 [==============================] - 27s 90ms/step - loss: 0.1688 - accuracy: 0.9252 - val_loss: 0.1712 - val_accuracy: 0.9247
# Epoch 174/500
# 296/296 [==============================] - 26s 89ms/step - loss: 0.1650 - accuracy: 0.9269 - val_loss: 0.1766 - val_accuracy: 0.9218
# Epoch 175/500
# 296/296 [==============================] - 27s 90ms/step - loss: 0.1643 - accuracy: 0.9268 - val_loss: 0.1793 - val_accuracy: 0.9248
# Epoch 176/500
# 296/296 [==============================] - 26s 88ms/step - loss: 0.1641 - accuracy: 0.9270 - val_loss: 0.1954 - val_accuracy: 0.9196
# Epoch 177/500
# 296/296 [==============================] - 27s 90ms/step - loss: 0.1648 - accuracy: 0.9274 - val_loss: 0.1813 - val_accuracy: 0.9219
# Epoch 178/500
# 296/296 [==============================] - 27s 91ms/step - loss: 0.1643 - accuracy: 0.9268 - val_loss: 0.1762 - val_accuracy: 0.9231
# Epoch 179/500
# 296/296 [==============================] - 27s 90ms/step - loss: 0.1624 - accuracy: 0.9279 - val_loss: 0.1697 - val_accuracy: 0.9253
# Epoch 180/500
# 296/296 [==============================] - 27s 90ms/step - loss: 0.1592 - accuracy: 0.9289 - val_loss: 0.1685 - val_accuracy: 0.9273
# 185/185 [==============================] - 5s 26ms/step - loss: 0.1732 - accuracy: 0.9251
# Test Loss: 0.1732
# Test Accuracy: 0.9251

# %%
def plot_history(history):
         # Plot training & validation loss values
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.axis([0, 350, 0, 1.0])
        plt.legend(['Train', 'Validation'], loc='upper right')
        plt.show()

        # Plot training & validation accuracy values
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('Model accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.axis([0, 350, 0, 1.0])
        plt.legend(['Train', 'Validation'], loc='lower right')
        plt.show()

def evaluate(model, theta, phi, sequence):
    loss, acc = model.evaluate({'theta_input': theta, 'phi_input': phi, 'sequence_input': sequence}, np.expand_dims(sequence, -1))
    print("Test Accuracy: {:.2f}".format(acc*100))
    print("Test Loss: {:.2f}".format(loss*100))

# 결과 그래프 그리기
plot_history(history)

# 모델 성능 평가
evaluate(model, theta_test, phi_test, sequence_test)
# Out:
# 185/185 [==============================] - 2s 10ms/step - loss: 0.1732 - accuracy: 0.9251
# Test Accuracy: 92.51
# Test Loss: 17.32

# %%
from tensorflow.keras.utils import plot_model

# 모델 구조 시각화
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# 데이터 저장

# %%
import os
from datetime import datetime
import pandas as pd

# Create a directory to store the results
dir = 'LO_results_dir'
if not os.path.exists(dir):
    os.makedirs(dir)

# CSV file name setup
date = datetime.now()
printdate = date.strftime('%Y%m%d_%H%M%S')
# filename = "/ByLO_dt_" + str(dt) + "_" + printdate + '.csv'
filename = "/ByLO_dt_" + "change_" + printdate + '.csv'

# Create an empty DataFrame and write to CSV file
saved_df = pd.DataFrame(columns=["Case", 'gate length', 'Theta', 'Phi', 'dt', 'combination', 'fidelity',
                           'total time', 'computing time'])
saved_df.to_csv(dir + filename, index=False)

# %% [markdown]
# 데이터 불러오기

# %%
import pandas as pd

df = pd.read_csv('../Data/using/dt_2.6/ByAstar_dt_2.6_1016.csv')
df = df[df['combination'] != '[]']
df = df.drop('Case', axis=1)
df_shuffled = df.sample(frac=1).reset_index(drop=True)

# 결측치나 data type 예외 처리 하지 않았으므로 데이터 사용에 주의 필요

thetas = df_shuffled['Theta'][:100]
phis = df_shuffled['Phi'][:100]
# dts = df_shuffled['dt'][:100]              # dt=2.6이 아닌 다른 값을 사용하는 경우
lists = df_shuffled['combination'][:100]

df_shuffled.head()
# Out:
#    gate length     Theta       Phi   dt  \
# 0           18  1.770482  1.391884  2.6
# 1           18  1.544460  3.668334  2.6
# 2           26  2.140590  1.198954  2.6
# 3           27  2.493033  0.376523  2.6
# 4           12  0.958101  0.437503  2.6
#
#                                          combination  total time  \
# 0  [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, ...        46.8
# 1  [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 2, 4, 0, 1, ...        46.8
# 2  [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, ...        67.6
# 3  [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, ...        70.2
# 4               [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 4]        31.2
#
#    computing time
# 0        7.383687
# 1      508.032867
# 2      374.243928
# 3       27.198607
# 4       44.993318

# %% [markdown]
# Base System

# %%
import numpy as np
from math import *
from scipy.linalg import expm, fractional_matrix_power

#########################################################################

# pauli matrix 
sx = np.array([[0,  1],     [1, 0]])
sy = np.array([[0, -1j],   [1j, 0]])
sz = np.array([[1, 0],     [0, -1]])
s0 = np.array([[1, 0],      [0, 1]])

# parameters(detuning factor)
v0 = 0.02           # Arbitrary settings, Actual speed : 0.04rad/μs
d0 = 0.15           # Arbitrary settings, Actual speed : 0.30rad/μs
# dt = 2.6 


# unitary operator
def unitary(dt, choice):
    
    # Select x,y-rotation direction.
    # [stay, +x, -x, +y, -y]
    choice_list = [0, 1, -1, 1, -1] 
    
    if choice < 3:
        # if choice = 0 ... only d0*sz
        Ham = (d0*sz+v0*choice_list[choice]*sx)
    else:
        Ham = (d0*sz+v0*choice_list[choice]*sy)

    # Creating a Unitary Operator for each of the four sections by Hamiltonian
    eigvals = np.linalg.eigh(Ham)[0]
    eigvecs = 1*np.linalg.eigh(Ham)[1]
    E = np.diag(eigvals)
    U_H = eigvecs.conj().T
    U_e = U_H.conj().T @ expm(-1j*E*dt) @ U_H
    
    return U_e


values = np.arange(1.80, 6.01, 0.01)
# 반올림하여 2자리 소수점까지만 표시
dt_values = [round(val, 2) for val in values]

unitary_choiceList = {}

for dt in dt_values:
    unitary_choiceList[dt] = [unitary(dt, i) for i in range(5)]


#########################################################################


# x-rotation operater
def Rx(theta):
    return np.matrix([  [cos(theta/2),  -1j*sin(theta/2)],
                        [-1j*sin(theta/2),  cos(theta/2)]])

# z-rotation operater
# Control by rotation only by Hamiltonian.
def Rz(phi): 
    return np.matrix([  [cos(phi/2)-1j*sin(phi/2),  0],
                        [0,  cos(phi/2)+1j*sin(phi/2)]])

# Calculating the Fidelity
def state_fidelity(rho_1, rho_2): 
    
    # rho_1(current state), rho_2(target state)
    # Calculate the fidelity after checking the dimensions of the two states.
    
    if np.shape(rho_1) != np.shape(rho_2):
        print("Dimensions of two states do not match.")
        return 0
    else:
        sqrt_rho_1 = fractional_matrix_power(rho_1, 1 / 2)
        rho_fidelity = np.trace(fractional_matrix_power(sqrt_rho_1 @ rho_2 @ sqrt_rho_1, 1 / 2)) ** 2
        return np.real(rho_fidelity)


#########################################################################


def fidelity(rho, dt, predicted_seq):

    u = s0
    
    for i in predicted_seq:
        u = unitary_choiceList[dt][i] @ u

    irho_final = u @ irho_init @ u.conj().T
    
    F = (state_fidelity(irho_final, rho))
    
    return  F


#########################################################################


init_wave = np.array([[1], [0]])
irho_init = np.kron(init_wave,init_wave.conj().T)

# %% [markdown]
# Find the best delta t function

# %%
def find_best_dt(seq):
     
    global input_rho
     
    my_dt = 0       # return value
    fid = 0         # final fidelity
    i_fid = 0       # temp fidelity
    
    for i in dt_values:
        
        i_fid = fidelity(input_rho, i, seq)
    
        if fid < i_fid:
            my_dt = i
            fid = i_fid
    
    return my_dt

# %% [markdown]
# Find the best sequence function

# %%
from itertools import product

def find_best_seq(seq, input_dt):
     
     global input_rho
     
     # when there is no over 0.9999 fidelity of seq, return original sequence
     final_seq = seq      # return value
     temp_seq = []
     # temp_fid = 0
     
     # for i in range(-1, -(len(seq)+1), -1):
     for i in range(-1, -9, -1):
          
          if i < -len(seq):             # if over length
               break
          
          front_seq = seq[:i]
          back_seq = seq[i:]
          
          for combination in product(range(5), repeat=len(back_seq)):
               temp_seq = front_seq + list(combination)
               
               fid = round(fidelity(input_rho, input_dt, temp_seq), 5)
               
               if fid > 0.9999:
                    final_seq = temp_seq
                    return final_seq
               
               # don't need these lines when we just want over 0.9999
               # if fid > temp_fid:
               #      final_seq = temp_seq
               #      temp_fid = fid

               # check the progress
               # print("=============================")
               # print(seq)
               # print(temp_seq)
               # print(final_seq)
               # print("=============================")
     
     return final_seq

# %% [markdown]
# Local Optimizer

# %%
import time

def local_optimizer(input_rho, input_seq, check_order, input_dt):
     
     first_fid = round(fidelity(input_rho, input_dt, input_seq), 5)        # default dt=2.6

     if first_fid >= 0.9999:
          
          output_dt = input_dt
          output_seq = input_seq
          last_fid = first_fid
          computing_t = 0
          total_t = output_dt * len(output_seq)
          print("        ** input data is already over 0.9999 **", end='\n')

          return output_dt, output_seq, first_fid, last_fid, total_t, computing_t


     start_time = time.time()

     if check_order == False:
          print("        ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##", end='\n')
          output_dt = find_best_dt(input_seq)
     else:
          output_dt = input_dt
     
     output_seq = find_best_seq(input_seq, output_dt)
     
     mid_fid = round(fidelity(input_rho, output_dt, output_seq), 5)
     
     if mid_fid < 0.9999:
          print("        ## after seq check, under 0.9999 -> need dt check ##", end='\n')
          output_dt = find_best_dt(output_seq)
     
     end_time = time.time()
     

     last_fid = round(fidelity(input_rho, output_dt, output_seq), 5)
          
     computing_t = end_time - start_time
     total_t = output_dt * len(output_seq)
     
     return output_dt, output_seq, first_fid, last_fid, total_t, computing_t

# %% [markdown]
# Main Part

# %%
case = 0

for input_theta, input_phi, input_sequence in zip(thetas, phis, lists):  
     # for input_theta, input_phi, input_dt, input_sequence in zip(thetas, phis, dts, lists):  
     
     # making rho
     target_U = Rz(input_phi) @ Rx(input_theta)
     input_rho = target_U @ irho_init @ target_U.conj().T
     
     # object to list
     input_sequence = eval(input_sequence)     
     
     # order == True ... theta > 90 : seq -> dt
     # order == False .. theta <= 90 : dt -> seq (-> dt)
     if input_theta > np.deg2rad(90):        # order True
          order = True
     else:                                   # order False
          order = False
     
     # if there is not defined dt value
     input_dt = 2.6
     
     # get values
     output_dt, output_sequence, first_fidelity, last_fidelity, total_time, computing_time = local_optimizer(input_rho, input_sequence, order, input_dt)
     
     # save values
     case += 1
     output = [['case' + str(case), len(output_sequence), input_theta, input_phi, 
                    output_dt, output_sequence, last_fidelity, total_time, computing_time]]
    
     # Create DataFrame and append to CSV file
     saved_df = pd.DataFrame(output, columns=["Case", 'gate length', 'Theta', 'Phi', 
                                                  'dt', 'combination', 'fidelity', 'total time', 'computing time'])
     saved_df.to_csv(dir + filename, mode='a', header=False, index=False)

     # Result output
     print(f"""
     -----------------------------------------------------------------------------------------------------------------------
     theta = {input_theta}
     phi = {input_phi}
     input_dt = {input_dt}
     output_dt : {output_dt}
     input_sequence : {input_sequence}
     first_fidelity : {first_fidelity}
     output_sequence : {output_sequence}
     last_fidelity : {last_fidelity}
     total_time : {total_time}
     computing_time : {computing_time}
     -----------------------------------------------------------------------------------------------------------------------
     """)
     
     # check progress
     print("%%%%%%%%%%%%%%%%%%%%%%%%%")
     print(case, "/", len(df_shuffled))
# Out:
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.770482239
#      phi = 1.391883644
#      input_dt = 2.6
#      output_dt : 2.58
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      first_fidelity : 0.9956
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      last_fidelity : 0.99698
#      total_time : 46.44
#      computing_time : 1314.7816259860992
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 1 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.544460466
#      phi = 3.668333632
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 2, 4, 0, 1, 3, 2, 2]
#      first_fidelity : 0.99059
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 2, 4, 0, 1, 3, 2, 2]
#      last_fidelity : 0.99059
#      total_time : 46.800000000000004
#      computing_time : 1380.8504629135132
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 2 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.140590409
#      phi = 1.198953563
#      input_dt = 2.6
#      output_dt : 2.57
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 0, 2, 3]
#      first_fidelity : 0.99246
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 0, 2, 3]
#      last_fidelity : 0.99932
#      total_time : 66.82
#      computing_time : 1206.9996755123138
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 3 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.493032928237467
#      phi = 0.3765226603324151
#      input_dt = 2.6
#      output_dt : 2.58
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      first_fidelity : 0.99456
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.9997
#      total_time : 69.66
#      computing_time : 1021.5204200744629
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 4 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.958101016
#      phi = 0.437503314
#      input_dt = 2.6
#      output_dt : 2.51
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 4]
#      first_fidelity : 0.99392
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 4]
#      last_fidelity : 0.99999
#      total_time : 30.119999999999997
#      computing_time : 0.868149995803833
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 5 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.9956199024790192
#      phi = 2.1068446475385603
#      input_dt = 2.6
#      output_dt : 2.56
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 3]
#      first_fidelity : 0.99883
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 3]
#      last_fidelity : 0.99995
#      total_time : 28.16
#      computing_time : 0.8506124019622803
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 6 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.378948136
#      phi = 4.068186694
#      input_dt = 2.6
#      output_dt : 2.63
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2]
#      first_fidelity : 0.99009
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2]
#      last_fidelity : 0.99679
#      total_time : 63.12
#      computing_time : 1024.466398715973
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 7 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.309787185
#      phi = 3.549308533
#      input_dt = 2.6
#      output_dt : 2.57
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 2, 3, 4]
#      first_fidelity : 0.99259
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 2, 3, 4]
#      last_fidelity : 0.99931
#      total_time : 69.39
#      computing_time : 1048.395653963089
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 8 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.638152533
#      phi = 1.707816867
#      input_dt = 2.6
#      output_dt : 2.63
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      first_fidelity : 0.99095
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      last_fidelity : 0.99813
#      total_time : 71.00999999999999
#      computing_time : 1178.3145081996918
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 9 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.623061175
#      phi = 5.647276509
#      input_dt = 2.6
#      output_dt : 2.62
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      first_fidelity : 0.99568
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      last_fidelity : 0.99992
#      total_time : 73.36
#      computing_time : 1165.497064590454
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 10 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.4565217853714943
#      phi = 4.170131229177713
#      input_dt = 2.6
#      output_dt : 3.05
#      input_sequence : [3, 3, 2, 2]
#      first_fidelity : 0.99585
#      output_sequence : [3, 3, 2, 2]
#      last_fidelity : 0.99961
#      total_time : 12.2
#      computing_time : 4.367238998413086
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 11 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.624020481
#      phi = 4.872090269
#      input_dt = 2.6
#      output_dt : 2.63
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      first_fidelity : 0.99059
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      last_fidelity : 0.99871
#      total_time : 71.00999999999999
#      computing_time : 1187.8318166732788
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 12 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.979366862099762
#      phi = 4.833026177767187
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 3, 1, 4, 3, 0, 2]
#      first_fidelity : 0.99772
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 3, 1, 1, 3, 3, 2]
#      last_fidelity : 0.99999
#      total_time : 70.2
#      computing_time : 0.8348972797393799
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 13 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.360570531
#      phi = 6.147266679
#      input_dt = 2.6
#      output_dt : 2.47
#      input_sequence : [4, 4, 1]
#      first_fidelity : 0.99679
#      output_sequence : [4, 4, 1]
#      last_fidelity : 0.99695
#      total_time : 7.41
#      computing_time : 2.1678414344787598
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 14 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.995826247
#      phi = 5.037554007
#      input_dt = 2.6
#      output_dt : 2.7
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 4, 1]
#      first_fidelity : 0.99173
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 4, 1]
#      last_fidelity : 0.99846
#      total_time : 29.700000000000003
#      computing_time : 982.8927931785583
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 15 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.353877772
#      phi = 5.021488725
#      input_dt = 2.6
#      output_dt : 2.57
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 0, 1]
#      first_fidelity : 0.99275
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 0, 1]
#      last_fidelity : 0.99894
#      total_time : 69.39
#      computing_time : 975.1124551296234
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 16 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.8228082033639543
#      phi = 2.337067385733284
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 2, 1, 1]
#      first_fidelity : 0.99545
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 2, 2, 4, 4, 1, 3]
#      last_fidelity : 0.99996
#      total_time : 85.8
#      computing_time : 150.17833137512207
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 17 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.260556951
#      phi = 5.29812842
#      input_dt = 2.6
#      output_dt : 5.4
#      input_sequence : [4]
#      first_fidelity : 0.99343
#      output_sequence : [4]
#      last_fidelity : 0.99823
#      total_time : 5.4
#      computing_time : 1.5956251621246338
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 18 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.857709532
#      phi = 1.630645192
#      input_dt = 2.6
#      output_dt : 2.67
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 0]
#      first_fidelity : 0.99753
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 0]
#      last_fidelity : 0.99998
#      total_time : 26.7
#      computing_time : 0.8833966255187988
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 19 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.989241329
#      phi = 3.531312159
#      input_dt = 2.6
#      output_dt : 2.49
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 3]
#      first_fidelity : 0.99001
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 0, 3, 3, 2]
#      last_fidelity : 0.99995
#      total_time : 29.880000000000003
#      computing_time : 1.3334782123565674
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 20 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.885889923
#      phi = 5.818754728
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1]
#      first_fidelity : 0.99061
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1]
#      last_fidelity : 0.99061
#      total_time : 75.4
#      computing_time : 972.6862926483154
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 21 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.58377561
#      phi = 4.29040474
#      input_dt = 2.6
#      output_dt : 2.46
#      input_sequence : [3, 3, 2, 2, 2]
#      first_fidelity : 0.99138
#      output_sequence : [3, 3, 2, 2, 2]
#      last_fidelity : 0.99232
#      total_time : 12.3
#      computing_time : 8.910193681716919
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 22 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.364281383
#      phi = 0.201758901
#      input_dt = 2.6
#      output_dt : 2.62
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 1, 4]
#      first_fidelity : 0.99518
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 1, 4]
#      last_fidelity : 0.99991
#      total_time : 70.74000000000001
#      computing_time : 963.423800945282
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 23 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.77291737
#      phi = 4.605869161
#      input_dt = 2.6
#      output_dt : 2.61
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      first_fidelity : 0.9984
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      last_fidelity : 0.9994
#      total_time : 75.69
#      computing_time : 960.0538420677185
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 24 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.357634357
#      phi = 1.340176477
#      input_dt = 2.6
#      output_dt : 2.59
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      first_fidelity : 0.99808
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      last_fidelity : 0.99946
#      total_time : 64.75
#      computing_time : 952.7613463401794
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 25 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.814507444
#      phi = 2.843640922
#      input_dt = 2.6
#      output_dt : 2.72
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 3, 3, 2]
#      first_fidelity : 0.99101
#      output_sequence : [3, 3, 2, 2, 4, 1, 0, 3, 3, 3]
#      last_fidelity : 0.99993
#      total_time : 27.200000000000003
#      computing_time : 3.6696057319641113
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 26 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.755657942
#      phi = 1.846516756
#      input_dt = 2.6
#      output_dt : 2.65
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 3, 2]
#      first_fidelity : 0.99839
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 3, 2]
#      last_fidelity : 0.99957
#      total_time : 26.5
#      computing_time : 930.9768738746643
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 27 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.42301642
#      phi = 0.148126098
#      input_dt = 2.6
#      output_dt : 2.98
#      input_sequence : [4, 4, 1]
#      first_fidelity : 0.99514
#      output_sequence : [4, 4, 1]
#      last_fidelity : 0.99665
#      total_time : 8.94
#      computing_time : 1.888627290725708
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 28 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.63014892
#      phi = 0.41719264
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 4, 1, 1, 2, 2, 2, 4, 1, 1]
#      first_fidelity : 0.99178
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 4, 1, 1, 2, 2, 2, 4, 1, 1]
#      last_fidelity : 0.99178
#      total_time : 49.4
#      computing_time : 945.2784593105316
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 29 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.679088204
#      phi = 3.041286117
#      input_dt = 2.6
#      output_dt : 2.65
#      input_sequence : [3, 3, 2, 2, 4, 1, 3, 3, 0, 2]
#      first_fidelity : 0.99883
#      output_sequence : [3, 3, 2, 2, 4, 1, 3, 2, 3, 2]
#      last_fidelity : 0.99991
#      total_time : 26.5
#      computing_time : 0.9949324131011963
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 30 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.092010555
#      phi = 0.506327559
#      input_dt = 2.6
#      output_dt : 2.5
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      first_fidelity : 0.99019
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.99697
#      total_time : 27.5
#      computing_time : 930.5579283237457
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 31 / 27806
#         ** input data is already over 0.9999 **
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.006673665
#      phi = 4.617952623
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 4, 3, 0, 0]
#      first_fidelity : 0.99995
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 4, 3, 0, 0]
#      last_fidelity : 0.99995
#      total_time : 67.60000000000001
#      computing_time : 0
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 32 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.434049212
#      phi = 2.399859754
#      input_dt = 2.6
#      output_dt : 3.24
#      input_sequence : [1, 3, 3]
#      first_fidelity : 0.99333
#      output_sequence : [1, 3, 3]
#      last_fidelity : 0.99757
#      total_time : 9.72
#      computing_time : 1.912808895111084
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 33 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.632422369
#      phi = 2.678738543
#      input_dt = 2.6
#      output_dt : 2.58
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      first_fidelity : 0.99032
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      last_fidelity : 0.9936
#      total_time : 69.66
#      computing_time : 949.1696872711182
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 34 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.99219729
#      phi = 5.874617166
#      input_dt = 2.6
#      output_dt : 2.63
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2]
#      first_fidelity : 0.99014
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2]
#      last_fidelity : 0.99668
#      total_time : 84.16
#      computing_time : 952.4836132526398
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 35 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.846727334
#      phi = 4.465804314
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 3, 0, 0]
#      first_fidelity : 0.99543
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 0, 1, 1, 3, 3, 2]
#      last_fidelity : 0.99992
#      total_time : 85.8
#      computing_time : 9.262918949127197
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 36 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.2406428068826962
#      phi = 6.241379633925672
#      input_dt = 2.6
#      output_dt : 2.61
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 2, 3, 0, 4, 3, 4]
#      first_fidelity : 0.99976
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 2, 3, 0, 4, 3, 4]
#      last_fidelity : 0.99999
#      total_time : 46.98
#      computing_time : 0.807471752166748
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 37 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.330310882
#      phi = 1.433066695
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 0, 3]
#      first_fidelity : 0.99945
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 0]
#      last_fidelity : 0.99998
#      total_time : 67.60000000000001
#      computing_time : 0.025998353958129883
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 38 / 27806
#         ** input data is already over 0.9999 **
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.63967798
#      phi = 1.37674157
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [1, 1, 3, 3, 2, 4, 1, 1, 1, 2]
#      first_fidelity : 0.99997
#      output_sequence : [1, 1, 3, 3, 2, 4, 1, 1, 1, 2]
#      last_fidelity : 0.99997
#      total_time : 26.0
#      computing_time : 0
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 39 / 27806
#         ** input data is already over 0.9999 **
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.090629623
#      phi = 1.443238111
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 2, 3, 0]
#      first_fidelity : 0.99995
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 2, 3, 0]
#      last_fidelity : 0.99995
#      total_time : 67.60000000000001
#      computing_time : 0
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 40 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 3.099299933
#      phi = 3.463726095
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 3]
#      first_fidelity : 0.992
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 3]
#      last_fidelity : 0.992
#      total_time : 83.2
#      computing_time : 955.1761293411255
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 41 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.26784422
#      phi = 5.72304189
#      input_dt = 2.6
#      output_dt : 6.0
#      input_sequence : [4]
#      first_fidelity : 0.99059
#      output_sequence : [4]
#      last_fidelity : 0.99897
#      total_time : 6.0
#      computing_time : 1.5459067821502686
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 42 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.678386942
#      phi = 0.856234914
#      input_dt = 2.6
#      output_dt : 2.73
#      input_sequence : [2, 2, 4, 4, 1, 1]
#      first_fidelity : 0.99611
#      output_sequence : [2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.99758
#      total_time : 16.38
#      computing_time : 37.9826717376709
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 43 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.325102081
#      phi = 4.031350667
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 4]
#      first_fidelity : 0.99538
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 3, 3, 2]
#      last_fidelity : 0.99996
#      total_time : 67.60000000000001
#      computing_time : 0.7362809181213379
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 44 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.038437205
#      phi = 3.005237856
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 3, 4, 3, 4]
#      first_fidelity : 0.99932
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 3, 4, 0, 3]
#      last_fidelity : 0.99993
#      total_time : 67.60000000000001
#      computing_time : 0.0209963321685791
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 45 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.593928894
#      phi = 3.248715797
#      input_dt = 2.6
#      output_dt : 2.63
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      first_fidelity : 0.99374
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      last_fidelity : 0.99939
#      total_time : 71.00999999999999
#      computing_time : 947.494226694107
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 46 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.436933519
#      phi = 3.480106254
#      input_dt = 2.6
#      output_dt : 2.59
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 4]
#      first_fidelity : 0.99802
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 4]
#      last_fidelity : 0.9995
#      total_time : 69.92999999999999
#      computing_time : 946.9417428970337
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 47 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.919517728
#      phi = 0.606832822
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 4, 4]
#      first_fidelity : 0.99964
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 4, 4]
#      last_fidelity : 0.99964
#      total_time : 85.8
#      computing_time : 953.4089395999908
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 48 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.38091171
#      phi = 1.430607855
#      input_dt = 2.6
#      output_dt : 2.51
#      input_sequence : [1, 1, 3]
#      first_fidelity : 0.99576
#      output_sequence : [1, 1, 3]
#      last_fidelity : 0.99585
#      total_time : 7.529999999999999
#      computing_time : 1.8757820129394531
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 49 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.587459226
#      phi = 1.157109568
#      input_dt = 2.6
#      output_dt : 2.65
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 1, 3, 3, 3, 3, 2, 2, 4, 4, 1, 1]
#      first_fidelity : 0.99062
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 1, 3, 3, 3, 3, 2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.9975
#      total_time : 47.699999999999996
#      computing_time : 950.6783504486084
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 50 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.6997356775489645
#      phi = 3.143007730021993
#      input_dt = 2.6
#      output_dt : 2.62
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      first_fidelity : 0.99837
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      last_fidelity : 0.99998
#      total_time : 47.160000000000004
#      computing_time : 940.0704209804535
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 51 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.680678234
#      phi = 5.361232087
#      input_dt = 2.6
#      output_dt : 2.57
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      first_fidelity : 0.99743
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      last_fidelity : 0.99995
#      total_time : 46.26
#      computing_time : 940.427577495575
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 52 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.995800739
#      phi = 5.542524028
#      input_dt = 2.6
#      output_dt : 2.64
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      first_fidelity : 0.99853
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      last_fidelity : 0.99943
#      total_time : 26.400000000000002
#      computing_time : 925.4517834186554
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 53 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.380208876
#      phi = 1.58549613
#      input_dt = 2.6
#      output_dt : 3.58
#      input_sequence : [1, 3]
#      first_fidelity : 0.9907
#      output_sequence : [1, 3]
#      last_fidelity : 0.99485
#      total_time : 7.16
#      computing_time : 1.644160509109497
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 54 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 3.086976977
#      phi = 2.855488526
#      input_dt = 2.6
#      output_dt : 2.61
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1]
#      first_fidelity : 0.99103
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1]
#      last_fidelity : 0.99256
#      total_time : 83.52
#      computing_time : 950.6244330406189
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 55 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.970049465
#      phi = 5.622972588
#      input_dt = 2.6
#      output_dt : 2.64
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      first_fidelity : 0.99158
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      last_fidelity : 0.9985
#      total_time : 52.800000000000004
#      computing_time : 940.5160791873932
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 56 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.002131885
#      phi = 3.879003288
#      input_dt = 2.6
#      output_dt : 2.59
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2]
#      first_fidelity : 0.99877
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2]
#      last_fidelity : 0.99881
#      total_time : 25.9
#      computing_time : 924.5271146297455
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 57 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.487891561
#      phi = 4.662355994
#      input_dt = 2.6
#      output_dt : 2.62
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      first_fidelity : 0.99713
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      last_fidelity : 0.99958
#      total_time : 68.12
#      computing_time : 949.8761444091797
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 58 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.3309406296929091
#      phi = 4.036597479003534
#      input_dt = 2.6
#      output_dt : 3.51
#      input_sequence : [2, 2]
#      first_fidelity : 0.99467
#      output_sequence : [2, 2]
#      last_fidelity : 0.99703
#      total_time : 7.02
#      computing_time : 1.6398348808288574
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 59 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.742429122
#      phi = 3.205400861
#      input_dt = 2.6
#      output_dt : 2.65
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 0, 0, 2]
#      first_fidelity : 0.99882
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 0, 3, 4]
#      last_fidelity : 0.99993
#      total_time : 26.5
#      computing_time : 0.9011523723602295
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 60 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.605161857053605
#      phi = 1.082710883417603
#      input_dt = 2.6
#      output_dt : 2.58
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      first_fidelity : 0.99009
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      last_fidelity : 0.99481
#      total_time : 69.66
#      computing_time : 947.3420350551605
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 61 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.855360541
#      phi = 5.650349063
#      input_dt = 2.6
#      output_dt : 2.62
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 0, 2]
#      first_fidelity : 0.99516
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 0, 2]
#      last_fidelity : 0.99881
#      total_time : 86.46000000000001
#      computing_time : 962.4997735023499
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 62 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.650532368
#      phi = 5.80852563
#      input_dt = 2.6
#      output_dt : 2.62
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 1, 3, 2, 2]
#      first_fidelity : 0.992
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 1, 3, 2, 2]
#      last_fidelity : 0.99637
#      total_time : 86.46000000000001
#      computing_time : 955.2148418426514
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 63 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.866833044
#      phi = 2.559241722
#      input_dt = 2.6
#      output_dt : 2.65
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 2]
#      first_fidelity : 0.99813
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 2]
#      last_fidelity : 0.99941
#      total_time : 26.5
#      computing_time : 926.2952260971069
#      -----------------------------------------------------------------------------------------------------------------------
#
# ...
#      first_fidelity : 0.99992
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 3, 3]
#      last_fidelity : 0.99992
#      total_time : 46.800000000000004
#      computing_time : 0
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 79 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.641105672
#      phi = 2.765048134
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 4, 2, 1, 4, 3]
#      first_fidelity : 0.99916
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 0, 2, 2, 4, 2, 1, 1, 3]
#      last_fidelity : 0.99994
#      total_time : 85.8
#      computing_time : 276.3801131248474
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 80 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.859863379
#      phi = 0.787855756
#      input_dt = 2.6
#      output_dt : 2.62
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      first_fidelity : 0.99221
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.99309
#      total_time : 47.160000000000004
#      computing_time : 955.5369362831116
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 81 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.771950733
#      phi = 4.792103382
#      input_dt = 2.6
#      output_dt : 2.62
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      first_fidelity : 0.99545
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      last_fidelity : 0.99966
#      total_time : 75.98
#      computing_time : 953.2504937648773
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 82 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.16688991
#      phi = 1.171613663
#      input_dt = 2.6
#      output_dt : 2.63
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 4, 4, 4]
#      first_fidelity : 0.99008
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 4, 4, 4]
#      last_fidelity : 0.99951
#      total_time : 68.38
#      computing_time : 949.0059435367584
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 83 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.408942382
#      phi = 4.074998445
#      input_dt = 2.6
#      output_dt : 3.37
#      input_sequence : [3, 2, 2]
#      first_fidelity : 0.99373
#      output_sequence : [3, 2, 2]
#      last_fidelity : 0.99912
#      total_time : 10.11
#      computing_time : 1.9230210781097412
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 84 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.279523328
#      phi = 1.331009721
#      input_dt = 2.6
#      output_dt : 4.46
#      input_sequence : [1, 1]
#      first_fidelity : 0.99411
#      output_sequence : [1, 1]
#      last_fidelity : 0.99989
#      total_time : 8.92
#      computing_time : 1.6711342334747314
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 85 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 3.0246023
#      phi = 2.582128261
#      input_dt = 2.6
#      output_dt : 2.59
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 1]
#      first_fidelity : 0.99686
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 1]
#      last_fidelity : 0.99753
#      total_time : 85.47
#      computing_time : 953.6651861667633
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 86 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.874912586
#      phi = 2.77520816
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 1]
#      first_fidelity : 0.99981
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 0, 1, 3]
#      last_fidelity : 0.99999
#      total_time : 85.8
#      computing_time : 1.2868006229400635
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 87 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.764883487
#      phi = 1.930178441
#      input_dt = 2.6
#      output_dt : 2.68
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 3, 3, 0]
#      first_fidelity : 0.99593
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 3, 2, 3]
#      last_fidelity : 0.99995
#      total_time : 29.48
#      computing_time : 0.8732073307037354
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 88 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.39242996
#      phi = 1.20426662
#      input_dt = 2.6
#      output_dt : 2.58
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      first_fidelity : 0.99616
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      last_fidelity : 0.99995
#      total_time : 67.08
#      computing_time : 952.6409890651703
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 89 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.3457377
#      phi = 0.33957196
#      input_dt = 2.6
#      output_dt : 2.63
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 1, 3, 3, 2, 3, 2, 4, 4, 4, 4]
#      first_fidelity : 0.99773
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 1, 3, 3, 2, 3, 2, 2, 1, 4, 1]
#      last_fidelity : 0.99991
#      total_time : 49.97
#      computing_time : 1.6603848934173584
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 90 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.078415979
#      phi = 0.539102217
#      input_dt = 2.6
#      output_dt : 2.51
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      first_fidelity : 0.99308
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.99802
#      total_time : 27.61
#      computing_time : 941.5257813930511
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 91 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.7506098111812038
#      phi = 4.065365995423374
#      input_dt = 2.6
#      output_dt : 2.65
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2]
#      first_fidelity : 0.99169
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2]
#      last_fidelity : 0.99952
#      total_time : 47.699999999999996
#      computing_time : 955.2944824695587
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 92 / 27806
#         ** input data is already over 0.9999 **
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.8864841031972323
#      phi = 3.2346955776426665
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 2, 2]
#      first_fidelity : 1.0
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 2, 2]
#      last_fidelity : 1.0
#      total_time : 26.0
#      computing_time : 0
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 93 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.599608279
#      phi = 0.900782567
#      input_dt = 2.6
#      output_dt : 2.71
#      input_sequence : [1, 1, 3, 3, 2, 4, 1, 1, 3]
#      first_fidelity : 0.99473
#      output_sequence : [1, 1, 1, 2, 2, 4, 1, 1, 3]
#      last_fidelity : 0.99993
#      total_time : 24.39
#      computing_time : 83.7804012298584
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 94 / 27806
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.502512229
#      phi = 3.226360468
#      input_dt = 2.6
#      output_dt : 2.62
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      first_fidelity : 0.99506
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      last_fidelity : 0.99941
#      total_time : 70.74000000000001
#      computing_time : 959.9411945343018
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 95 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.634436423758656
#      phi = 3.6977052829069184
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 4, 1, 1, 4]
#      first_fidelity : 0.99004
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 0, 1, 1, 3]
#      last_fidelity : 0.99992
#      total_time : 85.8
#      computing_time : 6.522166728973389
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 96 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.58733795
#      phi = 1.769847136
#      input_dt = 2.6
#      output_dt : 2.84
#      input_sequence : [4, 4, 1, 1, 3]
#      first_fidelity : 0.9955
#      output_sequence : [4, 4, 1, 1, 3]
#      last_fidelity : 0.99825
#      total_time : 14.2
#      computing_time : 8.981798887252808
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 97 / 27806
#         ** input data is already over 0.9999 **
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.2503983309204267
#      phi = 3.077333710551056
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 1]
#      first_fidelity : 0.99991
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 1]
#      last_fidelity : 0.99991
#      total_time : 67.60000000000001
#      computing_time : 0
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 98 / 27806
#         ## before seq check, under 0.9999, under theta pi/2 -> need dt check ##
#         ## after seq check, under 0.9999 -> need dt check ##
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.977031254
#      phi = 2.449508446
#      input_dt = 2.6
#      output_dt : 2.67
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      first_fidelity : 0.99763
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      last_fidelity : 0.99988
#      total_time : 26.7
#      computing_time : 938.3098287582397
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 99 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.131576188
#      phi = 4.539038737
#      input_dt = 2.6
#      output_dt : 2.6
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 0, 3, 4, 0]
#      first_fidelity : 0.99986
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 0, 0, 0, 4]
#      last_fidelity : 0.99997
#      total_time : 67.60000000000001
#      computing_time : 0.06898856163024902
#      -----------------------------------------------------------------------------------------------------------------------
#
# %%%%%%%%%%%%%%%%%%%%%%%%%
# 100 / 27806

# %% [markdown]
# 결과 데이터 확인

# %%
import pandas as pd

result_df = pd.read_csv('../Local_Optimizer/LO_results_dir/ByLO_dt_change_20231206_150634.csv')

result_df.head()
# Out:
#     Case  gate length     Theta       Phi    dt  \
# 0  case1           18  1.770482  1.391884  2.58
# 1  case2           18  1.544460  3.668334  2.60
# 2  case3           26  2.140590  1.198954  2.57
# 3  case4           27  2.493033  0.376523  2.58
# 4  case5           12  0.958101  0.437503  2.51
#
#                                          combination  fidelity  total time  \
# 0  [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, ...   0.99698       46.44
# 1  [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 2, 4, 0, 1, ...   0.99059       46.80
# 2  [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, ...   0.99932       66.82
# 3  [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, ...   0.99970       69.66
# 4               [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 4]   0.99999       30.12
#
#    computing time
# 0     1314.781626
# 1     1380.850463
# 2     1206.999676
# 3     1021.520420
# 4        0.868150

# %%
result_df['fidelity'].mean()
# Out:
# 0.9984665000000001

# %%
df2 = result_df[result_df['fidelity'] >= 0.9999]

print(df2['fidelity'].mean())
df2.info()
# Out:
# 0.9999480487804878
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 4 to 99
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Case            41 non-null     object
#  1   gate length     41 non-null     int64
#  2   Theta           41 non-null     float64
#  3   Phi             41 non-null     float64
#  4   dt              41 non-null     float64
#  5   combination     41 non-null     object
#  6   fidelity        41 non-null     float64
#  7   total time      41 non-null     float64
#  8   computing time  41 non-null     float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 3.2+ KB

# %%
df3 = result_df[result_df['fidelity'] < 0.9999]

print(df3['fidelity'].mean())
df3.info()
# Out:
# 0.9974369491525422
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 0 to 98
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Case            59 non-null     object
#  1   gate length     59 non-null     int64
#  2   Theta           59 non-null     float64
#  3   Phi             59 non-null     float64
#  4   dt              59 non-null     float64
#  5   combination     59 non-null     object
#  6   fidelity        59 non-null     float64
#  7   total time      59 non-null     float64
#  8   computing time  59 non-null     float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 4.6+ KB

# %%
import matplotlib.pyplot as plt

# 그래프 표시
plt.scatter(result_df['Case'], result_df['fidelity'], alpha=1)
plt.xlabel('Case')
plt.ylabel('Fidelity')
plt.show()

# %%
min(result_df['fidelity'])
# Out:
# 0.99059

# %%
import numpy as np
from math import *
from scipy.linalg import expm, fractional_matrix_power

#########################################################################

# pauli matrix 
sx = np.array([[0,  1],     [1, 0]])
sy = np.array([[0, -1j],   [1j, 0]])
sz = np.array([[1, 0],     [0, -1]])
s0 = np.array([[1, 0],      [0, 1]])

# parameters(detuning factor)
v0 = 0.02           # Arbitrary settings, Actual speed : 0.04rad/μs
d0 = 0.15           # Arbitrary settings, Actual speed : 0.30rad/μs
# dt = 2.6 


# unitary operator
def unitary(dt, choice):
    
    # Select x,y-rotation direction.
    # [stay, +x, -x, +y, -y]
    choice_list = [0, 1, -1, 1, -1] 
    
    if choice < 3:
        # if choice = 0 ... only d0*sz
        Ham = (d0*sz+v0*choice_list[choice]*sx)
    else:
        Ham = (d0*sz+v0*choice_list[choice]*sy)

    # Creating a Unitary Operator for each of the four sections by Hamiltonian
    eigvals = np.linalg.eigh(Ham)[0]
    eigvecs = 1*np.linalg.eigh(Ham)[1]
    E = np.diag(eigvals)
    U_H = eigvecs.conj().T
    U_e = U_H.conj().T @ expm(-1j*E*dt) @ U_H
    
    return U_e


#########################################################################

# x-rotation operater
def Rx(theta):
    return np.matrix([  [cos(theta/2),    -1j*sin(theta/2)],
                        [-1j*sin(theta/2),    cos(theta/2)]])

# z-rotation operater
# Do not use Rz. Control by rotation only by Hamiltonian.
def Rz(phi): 
    return np.matrix([  [cos(phi/2)-1j*sin(phi/2),  0],
                        [0,  cos(phi/2)+1j*sin(phi/2)]])

# Calculating the Fidelity
def state_fidelity(rho_1, rho_2): 
    
    # rho_1(current state), rho_2(target state)
    # Calculate the fidelity after checking the dimensions of the two states.
    
    if np.shape(rho_1) != np.shape(rho_2):
        print("Dimensions of two states do not match.")
        return 0
    else:
        sqrt_rho_1 = fractional_matrix_power(rho_1, 1 / 2)
        fidelity = np.trace(fractional_matrix_power(sqrt_rho_1 @ rho_2 @ sqrt_rho_1, 1 / 2)) ** 2
        return np.real(fidelity)


#########################################################################

values = np.arange(1.80, 6.01, 0.01)
# 반올림하여 2자리 소수점까지만 표시
dt_values = [round(val, 2) for val in values]

unitary_choiceList = {}

for dt in dt_values:
    unitary_choiceList[dt] = [unitary(dt, i) for i in range(5)]


init_wave = np.array([[1], [0]])
irho_init = np.kron(init_wave,init_wave.conj().T)


def fidelity(rho, dt, predicted_seq):

    # predicted_seq = np.argmax(predicted_seq, axis=-1)
    # if type(predicted_seq) != list:
    #     predicted_seq = np.argmax(predicted_seq, axis=-1).astype(int).tolist()
    
    Uni = s0
    
    for i in predicted_seq:
        Uni = unitary_choiceList[dt][i] @ Uni

    irho_final = Uni @ irho_init @ Uni.conj().T
    
    F = (state_fidelity(irho_final, rho))
    
    return  F

# %%
# def rho_making(dt, predicted_comb):
     
#     # rho = np.matrix(irho_init)
#     rho = irho_init
    
#     for i in predicted_comb:
#         instant_U = unitary_choiceList[dt][i]
#         rho = (instant_U @ rho @ instant_U.conj().T)
     
#     return rho


def find_best_dt(seq):
     
    global input_rho
     
    my_dt = 0
    fid = 0         # final fidelity
    i_fid = 0       # temp fidelity
    
    for i in dt_values:
        
        # irho_new = rho_making(i, seq)
        # i_fid = state_fidelity(irho_new, input_rho)
        i_fid = fidelity(input_rho, i, seq)
    
        if fid < i_fid:
            my_dt = i
            fid = i_fid
    
    return my_dt

# %%
from itertools import product

def find_best_seq(seq):
     
     global input_rho
     
     final_seq = []
     temp_seq = []
     temp_fid = 0
     temp_dt = 2.6
     
     # for i in range(-1, -(len(seq)+1), -1):
     for i in range(-1, -9, -1):
          
          if i < -len(seq):
               break
          
          front_seq = seq[:i]
          back_seq = seq[i:]
          
          for combination in product(range(5), repeat=len(back_seq)):
               temp_seq = front_seq + list(combination)
               
               fid = fidelity(input_rho, temp_dt, temp_seq)     # default dt=2.6
               
               if fid > 0.99990:
                    final_seq = temp_seq
                    return temp_dt, final_seq
               elif fid > temp_fid:
                    final_seq = temp_seq
                    temp_fid = fid

               # print("=============================")
               # print(seq)
               # print(temp_seq)
               # print(final_seq)
               # print("=============================")

     if temp_fid < 0.99990:
          final_dt = find_best_dt(final_seq)
     else:
          final_dt = temp_dt
     
     return final_dt, final_seq

# %%
import time

def local_optimizer(input_rho, input_seq):

     input_dt = 2.6
     
     first_fid = fidelity(input_rho, input_dt, input_seq)        # default dt=2.6

     if first_fid > 0.99990:
          output_seq = input_seq
          output_dt = input_dt
          computing_t = 0
     else:
          start_time = time.time()
          
          output_dt, output_seq = find_best_seq(input_seq)
          
          end_time = time.time()
          computing_t = end_time - start_time

     last_fid = fidelity(input_rho, output_dt, output_seq)

     total_t = output_dt * len(output_seq)
     
     return output_dt, output_seq, first_fid, last_fid, total_t, computing_t

# %%
import os
from datetime import datetime
import pandas as pd

# Create a directory to store the results
dir = 'LO_results_dir'
if not os.path.exists(dir):
    os.makedirs(dir)

# CSV file name setup
date = datetime.now()
printdate = date.strftime('%Y%m%d_%H%M%S')
# filename = "/ByLO_dt_" + str(dt) + "_" + printdate + '.csv'
filename = "/ByLO_dt_" + "change_" + printdate + '.csv'

# Create an empty DataFrame and write to CSV file
saved_df = pd.DataFrame(columns=["Case", 'gate length', 'Theta', 'Phi', 'dt', 'combination', 'fidelity',
                           'total time', 'computing time'])
saved_df.to_csv(dir + filename, index=False)

# %%
import pandas as pd

df = pd.read_csv('../Data/using/dt_2.6/ByAstar_dt_2.6_1016.csv')
df = df[df['combination'] != '[]']
df = df.drop('Case', axis=1)
df_shuffled = df.sample(frac=1).reset_index(drop=True)

thetas = df_shuffled['Theta']
phis = df_shuffled['Phi']
lists = df_shuffled['combination']


df_shuffled.head()
# Out:
#    gate length     Theta       Phi   dt  \
# 0            4  0.456436  6.064581  2.6
# 1            3  0.457565  0.353785  2.6
# 2            3  0.436294  3.650060  2.6
# 3           27  2.604719  3.173633  2.6
# 4           26  2.315468  2.563921  2.6
#
#                                          combination  total time  \
# 0                                       [2, 4, 4, 1]        10.4
# 1                                          [4, 4, 1]         7.8
# 2                                          [3, 2, 2]         7.8
# 3  [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, ...        70.2
# 4  [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, ...        67.6
#
#    computing time
# 0        2.276737
# 1        0.504891
# 2        1.119246
# 3      243.809347
# 4       81.365145

# %%
case = 0

for input_theta, input_phi, input_sequence in zip(thetas, phis, lists):  

     target_U = Rz(input_phi) @ Rx(input_theta)
     input_rho = target_U @ irho_init @ target_U.conj().T
     
     output_dt, output_sequence, first_fidelity, last_fidelity, total_time, computing_time = local_optimizer(input_rho, eval(input_sequence))

     case += 1
     output = [['case' + str(case), len(output_sequence), input_theta, input_phi, output_dt, output_sequence, 
                    last_fidelity, total_time, computing_time]]
    
     # Create DataFrame and append to CSV file
     saved_df = pd.DataFrame(output, columns=["Case", 'gate length', 'Theta', 'Phi', 'dt', 'combination', 
                                                  'fidelity', 'total time', 'computing time'])
     saved_df.to_csv(dir + filename, mode='a', header=False, index=False)

     # Result output
     print(f"""
     -----------------------------------------------------------------------------------------------------------------------
     theta = {input_theta}
     phi = {input_phi}
     selected_dt : {output_dt}
     input_sequence : {input_sequence}
     first_fidelity : {first_fidelity}
     output_sequence : {output_sequence}
     last_fidelity : {last_fidelity}
     total_time : {total_time}
     computing_time : {computing_time}
     -----------------------------------------------------------------------------------------------------------------------
     """)
     
     print(case, "/", len(df_shuffled))
# Out:
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.456436264
#      phi = 6.064581288
#      selected_dt : 2.52
#      input_sequence : [2, 4, 4, 1]
#      first_fidelity : 0.996616516290931
#      output_sequence : [2, 4, 4, 1]
#      last_fidelity : 0.9967772877807698
#      total_time : 10.08
#      computing_time : 3.1913280487060547
#      -----------------------------------------------------------------------------------------------------------------------
#
# 1 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.457565174
#      phi = 0.353784602
#      selected_dt : 3.36
#      input_sequence : [4, 4, 1]
#      first_fidelity : 0.9909041227151381
#      output_sequence : [4, 4, 1]
#      last_fidelity : 0.9967969549522868
#      total_time : 10.08
#      computing_time : 1.3418395519256592
#      -----------------------------------------------------------------------------------------------------------------------
#
# 2 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.43629391
#      phi = 3.65006015
#      selected_dt : 2.78
#      input_sequence : [3, 2, 2]
#      first_fidelity : 0.9936588636759078
#      output_sequence : [3, 2, 2]
#      last_fidelity : 0.9940373735308329
#      total_time : 8.34
#      computing_time : 1.3035786151885986
#      -----------------------------------------------------------------------------------------------------------------------
#
# 3 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.604718576
#      phi = 3.1736331
#      selected_dt : 2.6
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      first_fidelity : 0.9958686695088851
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3]
#      last_fidelity : 0.9959385736250576
#      total_time : 70.2
#      computing_time : 1078.3981273174286
#      -----------------------------------------------------------------------------------------------------------------------
#
# 4 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.315468074
#      phi = 2.563920746
#      selected_dt : 2.61
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 1]
#      first_fidelity : 0.9926044265371663
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 1, 3]
#      last_fidelity : 0.9999762000107142
#      total_time : 67.86
#      computing_time : 1048.9215953350067
#      -----------------------------------------------------------------------------------------------------------------------
#
# 5 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.911650941
#      phi = 5.417739884
#      selected_dt : 2.64
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 2, 4]
#      first_fidelity : 0.9993675131806077
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 2, 4]
#      last_fidelity : 0.9999299839180353
#      total_time : 26.400000000000002
#      computing_time : 1020.7870361804962
#      -----------------------------------------------------------------------------------------------------------------------
#
# 6 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.185293853
#      phi = 2.082542754
#      selected_dt : 2.6
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 2, 2]
#      first_fidelity : 0.9962351353383676
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 0, 1, 3, 3, 2]
#      last_fidelity : 0.999987605973575
#      total_time : 67.60000000000001
#      computing_time : 2.1723344326019287
#      -----------------------------------------------------------------------------------------------------------------------
#
# 7 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.30841106
#      phi = 1.519813706
#      selected_dt : 2.6
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 2, 1, 3, 4]
#      first_fidelity : 0.999805847381223
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 2, 2, 3, 3]
#      last_fidelity : 0.9999548993451873
#      total_time : 46.800000000000004
#      computing_time : 0.20961833000183105
#      -----------------------------------------------------------------------------------------------------------------------
#
# 8 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.672446904
#      phi = 3.291721817
#      selected_dt : 2.62
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3]
#      first_fidelity : 0.9953731874399302
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3]
#      last_fidelity : 0.9975341992012562
#      total_time : 73.36
#      computing_time : 1042.4364709854126
#      -----------------------------------------------------------------------------------------------------------------------
#
# 9 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.840318304
#      phi = 5.202730037
#      selected_dt : 2.6
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 2, 4, 4, 3, 3, 3, 2, 4, 4, 1, 1, 3, 3, 2, 1, 2, 2]
#      first_fidelity : 0.9978179809794839
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 2, 4, 4, 3, 3, 3, 2, 4, 4, 1, 1, 1, 1, 3, 3, 2, 2]
#      last_fidelity : 0.9997806103079401
#      total_time : 70.2
#      computing_time : 1030.886387348175
#      -----------------------------------------------------------------------------------------------------------------------
#
# 10 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.281929468
#      phi = 0.995349047
#      selected_dt : 2.61
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 0]
#      first_fidelity : 0.9939140028615348
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 2, 2, 4, 4, 1]
#      last_fidelity : 0.9995454525136847
#      total_time : 67.86
#      computing_time : 1005.4783761501312
#      -----------------------------------------------------------------------------------------------------------------------
#
# 11 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.751880736
#      phi = 0.036384231
#      selected_dt : 2.6
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 2, 4, 3]
#      first_fidelity : 0.9967606206096024
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 3, 1]
#      last_fidelity : 0.9999742900444987
#      total_time : 26.0
#      computing_time : 0.305161714553833
#      -----------------------------------------------------------------------------------------------------------------------
#
# 12 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.775172642
#      phi = 0.988171698
#      selected_dt : 2.61
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 2, 4]
#      first_fidelity : 0.9956169015385948
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 2, 2, 4, 4]
#      last_fidelity : 0.9997126669586239
#      total_time : 86.13
#      computing_time : 1008.5158133506775
#      -----------------------------------------------------------------------------------------------------------------------
#
# 13 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.666632235
#      phi = 6.172433603
#      selected_dt : 2.61
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1]
#      first_fidelity : 0.9948157766329976
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1]
#      last_fidelity : 0.9956121279808292
#      total_time : 70.47
#      computing_time : 1003.4982075691223
#      -----------------------------------------------------------------------------------------------------------------------
#
# 14 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.403082022
#      phi = 0.14939774
#      selected_dt : 2.6
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 2, 1]
#      first_fidelity : 0.9943737063558619
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 4, 4]
#      last_fidelity : 0.9999740841613055
#      total_time : 70.2
#      computing_time : 0.22057819366455078
#      -----------------------------------------------------------------------------------------------------------------------
#
# 15 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.786002204
#      phi = 6.226418771
#      selected_dt : 2.61
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1]
#      first_fidelity : 0.997214711941589
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1]
#      last_fidelity : 0.9976800682169203
#      total_time : 46.98
#      computing_time : 994.8938553333282
#      -----------------------------------------------------------------------------------------------------------------------
#
# 16 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.481760666
#      phi = 0.170275546
#      selected_dt : 2.62
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4]
#      first_fidelity : 0.9930168938289636
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4]
#      last_fidelity : 0.9977165545971871
#      total_time : 68.12
#      computing_time : 1001.1553490161896
#      -----------------------------------------------------------------------------------------------------------------------
#
# 17 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.881829933
#      phi = 2.337649386
#      selected_dt : 2.61
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      first_fidelity : 0.9904695023725046
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      last_fidelity : 0.9909482502924571
#      total_time : 46.98
#      computing_time : 997.3721125125885
#      -----------------------------------------------------------------------------------------------------------------------
#
# 18 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.254361475
#      phi = 5.001515128
#      selected_dt : 2.61
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 0, 3, 2]
#      first_fidelity : 0.9926570230930677
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 1, 3, 3, 2, 2]
#      last_fidelity : 0.9999785201793433
#      total_time : 70.47
#      computing_time : 1003.3682305812836
#      -----------------------------------------------------------------------------------------------------------------------
#
# 19 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.50451103
#      phi = 4.997974734
#      selected_dt : 2.59
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      first_fidelity : 0.9903126582633015
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 1]
#      last_fidelity : 0.9967118520801178
#      total_time : 69.92999999999999
#      computing_time : 1004.9789350032806
#      -----------------------------------------------------------------------------------------------------------------------
#
# 20 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.505946415
#      phi = 5.610604555
#      selected_dt : 2.92
#      input_sequence : [2, 2, 4, 4]
#      first_fidelity : 0.995090360544812
#      output_sequence : [2, 2, 4, 4]
#      last_fidelity : 0.9972974053412599
#      total_time : 11.68
#      computing_time : 2.464766263961792
#      -----------------------------------------------------------------------------------------------------------------------
#
# 21 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.934952754
#      phi = 3.251549415
#      selected_dt : 2.61
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 1]
#      first_fidelity : 0.9913166012455984
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 1]
#      last_fidelity : 0.9923925953234964
#      total_time : 86.13
#      computing_time : 1006.8377404212952
#      -----------------------------------------------------------------------------------------------------------------------
#
# 22 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.522563258
#      phi = 5.379073718
#      selected_dt : 2.64
#      input_sequence : [2, 2, 4, 4]
#      first_fidelity : 0.9939792061815746
#      output_sequence : [2, 2, 4, 4]
#      last_fidelity : 0.9940165521384084
#      total_time : 10.56
#      computing_time : 2.4500198364257812
#      -----------------------------------------------------------------------------------------------------------------------
#
# 23 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.224806513
#      phi = 0.815814696
#      selected_dt : 2.6
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 3, 3]
#      first_fidelity : 0.9904425505756373
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 0, 2, 4, 1, 1]
#      last_fidelity : 0.9999566464976708
#      total_time : 67.60000000000001
#      computing_time : 27.96818971633911
#      -----------------------------------------------------------------------------------------------------------------------
#
# 24 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.7895504615751412
#      phi = 0.91050871115355
#      selected_dt : 2.63
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      first_fidelity : 0.9911928419469275
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 2, 2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.995280094554692
#      total_time : 47.339999999999996
#      computing_time : 994.9212884902954
#      -----------------------------------------------------------------------------------------------------------------------
#
# 25 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.395278247
#      phi = 3.237239383
#      selected_dt : 2.6
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 1, 2]
#      first_fidelity : 0.9967323143273344
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 1, 3, 2]
#      last_fidelity : 0.9998715141573588
#      total_time : 70.2
#      computing_time : 1003.5506837368011
#      -----------------------------------------------------------------------------------------------------------------------
#
# 26 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 3.10168678
#      phi = 5.911253333
#      selected_dt : 2.61
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2]
#      first_fidelity : 0.991349459299422
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2]
#      last_fidelity : 0.9923981915492872
#      total_time : 83.52
#      computing_time : 1004.894285440445
#      -----------------------------------------------------------------------------------------------------------------------
#
# 27 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.984298184
#      phi = 6.186942478
#      selected_dt : 2.58
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1]
#      first_fidelity : 0.9987768778260638
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1]
#      last_fidelity : 0.9990370079810915
#      total_time : 25.8
#      computing_time : 977.2749540805817
#      -----------------------------------------------------------------------------------------------------------------------
#
# 28 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.104158191
#      phi = 4.785015778
#      selected_dt : 2.69
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      first_fidelity : 0.9908001045798701
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      last_fidelity : 0.9952182593895961
#      total_time : 26.9
#      computing_time : 1003.6036415100098
#      -----------------------------------------------------------------------------------------------------------------------
#
# 29 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.254799344
#      phi = 1.671346314
#      selected_dt : 3.22
#      input_sequence : [1, 3]
#      first_fidelity : 0.9987202027200003
#      output_sequence : [1, 3]
#      last_fidelity : 0.9998233346711073
#      total_time : 6.44
#      computing_time : 0.9025230407714844
#      -----------------------------------------------------------------------------------------------------------------------
#
# 30 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.5321384643292915
#      phi = 2.961274272638424
#      selected_dt : 2.69
#      input_sequence : [1, 1, 3, 3, 2]
#      first_fidelity : 0.9954734976605585
#      output_sequence : [1, 1, 3, 3, 3]
#      last_fidelity : 0.9973405041618845
#      total_time : 13.45
#      computing_time : 8.600743532180786
#      -----------------------------------------------------------------------------------------------------------------------
#
# 31 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.038437205
#      phi = 3.005237856
#      selected_dt : 2.6
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 3, 4, 3, 4]
#      first_fidelity : 0.9993199245443938
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 3, 4, 0, 3]
#      last_fidelity : 0.9999333960002393
#      total_time : 67.60000000000001
#      computing_time : 0.019396305084228516
#      -----------------------------------------------------------------------------------------------------------------------
#
# 32 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.64520449
#      phi = 2.176139972
#      selected_dt : 2.6
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      first_fidelity : 0.999627528583884
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      last_fidelity : 0.999627528583884
#      total_time : 72.8
#      computing_time : 1000.3673870563507
#      -----------------------------------------------------------------------------------------------------------------------
#
# 33 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.779644676
#      phi = 4.760279662
#      selected_dt : 2.6
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 1, 3, 1, 2]
#      first_fidelity : 0.9998711390185547
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 1, 4, 1, 1, 3, 3, 2]
#      last_fidelity : 0.9999467498915108
#      total_time : 88.4
#      computing_time : 582.7187049388885
#      -----------------------------------------------------------------------------------------------------------------------
#
# 34 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.436171714
#      phi = 3.057970404
#      selected_dt : 2.68
#      input_sequence : [3, 3, 2]
#      first_fidelity : 0.9928587406229632
#      output_sequence : [3, 3, 2]
#      last_fidelity : 0.9929247125348241
#      total_time : 8.040000000000001
#      computing_time : 1.1877026557922363
#      -----------------------------------------------------------------------------------------------------------------------
#
# 35 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.7545939
#      phi = 0.566607288
#      selected_dt : 2.58
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      first_fidelity : 0.990602185446568
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 3, 2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.9955893697360939
#      total_time : 46.44
#      computing_time : 995.1171915531158
#      -----------------------------------------------------------------------------------------------------------------------
#
# 36 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.953861704
#      phi = 2.861119879
#      selected_dt : 2.6
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3]
#      first_fidelity : 0.9933433930752184
#      output_sequence : [3, 3, 2, 2, 2, 4, 1, 1, 1, 3, 2]
#      last_fidelity : 0.9999467749800202
#      total_time : 28.6
#      computing_time : 129.71964502334595
#      -----------------------------------------------------------------------------------------------------------------------
#
# 37 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.262535265
#      phi = 5.044072149
#      selected_dt : 2.62
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 1, 3, 3, 2, 4, 4]
#      first_fidelity : 0.9900601359849233
#      output_sequence : [3, 2, 2, 4, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      last_fidelity : 0.9967059276254223
#      total_time : 34.06
#      computing_time : 988.3624165058136
#      -----------------------------------------------------------------------------------------------------------------------
#
# 38 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.143737558
#      phi = 2.952585695
#      selected_dt : 2.6
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 3, 3, 1, 0]
#      first_fidelity : 0.9998272572643208
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 3, 0, 1, 2]
#      last_fidelity : 0.9999036886028126
#      total_time : 67.60000000000001
#      computing_time : 0.07776379585266113
#      -----------------------------------------------------------------------------------------------------------------------
#
# 39 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.050963125
#      phi = 4.528420494
#      selected_dt : 2.59
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      first_fidelity : 0.9932172971716982
#      output_sequence : [2, 2, 4, 4, 4, 1, 3, 3, 2, 2, 4]
#      last_fidelity : 0.9983780509197012
#      total_time : 28.49
#      computing_time : 980.2134139537811
#      -----------------------------------------------------------------------------------------------------------------------
#
# 40 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.684477171
#      phi = 2.102244152
#      selected_dt : 2.65
#      input_sequence : [4, 4, 1, 1, 3, 3]
#      first_fidelity : 0.991242580584065
#      output_sequence : [4, 4, 1, 1, 1, 3]
#      last_fidelity : 0.9938033266701757
#      total_time : 15.899999999999999
#      computing_time : 39.209678173065186
#      -----------------------------------------------------------------------------------------------------------------------
#
# 41 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 3.09245093
#      phi = 5.99188081
#      selected_dt : 2.61
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2]
#      first_fidelity : 0.9910646455222488
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2]
#      last_fidelity : 0.9924332460352706
#      total_time : 83.52
#      computing_time : 1003.0708208084106
#      -----------------------------------------------------------------------------------------------------------------------
#
# 42 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.64588609
#      phi = 3.173879087
#      selected_dt : 2.62
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      first_fidelity : 0.9939585500757007
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      last_fidelity : 0.9975312701850448
#      total_time : 70.74000000000001
#      computing_time : 1003.5054755210876
#      -----------------------------------------------------------------------------------------------------------------------
#
# 43 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.573539656
#      phi = 5.281822714
#      selected_dt : 2.57
#      input_sequence : [3, 2, 2, 4, 4]
#      first_fidelity : 0.9963903476996122
#      output_sequence : [3, 2, 2, 4, 4]
#      last_fidelity : 0.9964324823703742
#      total_time : 12.85
#      computing_time : 8.503546714782715
#      -----------------------------------------------------------------------------------------------------------------------
#
# 44 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.9553708263874
#      phi = 0.948196271826121
#      selected_dt : 2.6
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 4, 2, 2, 0, 0]
#      first_fidelity : 0.9944998229882098
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 2, 2, 2, 4, 4]
#      last_fidelity : 0.9998196747738216
#      total_time : 67.60000000000001
#      computing_time : 998.1163959503174
#      -----------------------------------------------------------------------------------------------------------------------
#
# 45 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.951946415
#      phi = 6.141226136
#      selected_dt : 2.61
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1]
#      first_fidelity : 0.9980664534154754
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 4]
#      last_fidelity : 0.999139141976809
#      total_time : 26.099999999999998
#      computing_time : 977.235024690628
#      -----------------------------------------------------------------------------------------------------------------------
#
# 46 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.624636398
#      phi = 5.422627786
#      selected_dt : 2.61
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      first_fidelity : 0.991086421160814
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      last_fidelity : 0.9914062975731456
#      total_time : 67.86
#      computing_time : 1000.3913698196411
#      -----------------------------------------------------------------------------------------------------------------------
#
# 47 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.436891708
#      phi = 1.747996601
#      selected_dt : 2.6
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 1, 3, 0, 3]
#      first_fidelity : 0.9900135002514362
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 0, 4, 4, 4, 1, 1, 3, 3]
#      last_fidelity : 0.9999853793952412
#      total_time : 49.4
#      computing_time : 355.6447694301605
#      -----------------------------------------------------------------------------------------------------------------------
#
# 48 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.572488782
#      phi = 2.424877496
#      selected_dt : 2.62
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      first_fidelity : 0.9932927250282719
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      last_fidelity : 0.9962045836681542
#      total_time : 68.12
#      computing_time : 1000.282276391983
#      -----------------------------------------------------------------------------------------------------------------------
#
# 49 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.5601703
#      phi = 1.208911486
#      selected_dt : 2.58
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      first_fidelity : 0.9961941337466607
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3]
#      last_fidelity : 0.9986174263712305
#      total_time : 69.66
#      computing_time : 1000.9295840263367
#      -----------------------------------------------------------------------------------------------------------------------
#
# 50 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.389688553
#      phi = 3.251618043
#      selected_dt : 2.6
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 0, 3]
#      first_fidelity : 0.9977276579704571
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 3, 3, 3]
#      last_fidelity : 0.9998169289985538
#      total_time : 70.2
#      computing_time : 1002.5030801296234
#      -----------------------------------------------------------------------------------------------------------------------
#
# 51 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.494754449
#      phi = 2.020803519
#      selected_dt : 2.6
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      first_fidelity : 0.9929728560293453
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 2]
#      last_fidelity : 0.994003268022217
#      total_time : 67.60000000000001
#      computing_time : 998.2349452972412
#      -----------------------------------------------------------------------------------------------------------------------
#
# 52 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.569901094
#      phi = 2.65718646
#      selected_dt : 2.59
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2]
#      first_fidelity : 0.9909146687548405
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 2, 2]
#      last_fidelity : 0.9928843166939133
#      total_time : 69.92999999999999
#      computing_time : 1006.5722904205322
#      -----------------------------------------------------------------------------------------------------------------------
#
# 53 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.404932856
#      phi = 4.468856113
#      selected_dt : 2.59
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2]
#      first_fidelity : 0.9951631378481417
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      last_fidelity : 0.9999270580238677
#      total_time : 67.34
#      computing_time : 1004.2957127094269
#      -----------------------------------------------------------------------------------------------------------------------
#
# 54 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.237827206
#      phi = 4.857223698
#      selected_dt : 2.62
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4]
#      first_fidelity : 0.9947827776538128
#      output_sequence : [3, 3, 2, 2, 4, 1, 1, 1, 3, 3, 2, 2, 4]
#      last_fidelity : 0.9991480500279529
#      total_time : 34.06
#      computing_time : 1001.9444017410278
#      -----------------------------------------------------------------------------------------------------------------------
#
# 55 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.7648530851025344
#      phi = 0.8426065690783962
#      selected_dt : 2.63
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      first_fidelity : 0.9964262746019661
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.998916198926607
#      total_time : 47.339999999999996
#      computing_time : 995.7986769676208
#      -----------------------------------------------------------------------------------------------------------------------
#
# 56 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.616650981
#      phi = 5.879081444
#      selected_dt : 2.6
#      input_sequence : [4, 4, 1, 1, 3, 2, 2, 1, 2, 1]
#      first_fidelity : 0.9992839826378245
#      output_sequence : [4, 4, 1, 1, 3, 2, 2, 1, 1, 4]
#      last_fidelity : 0.9999990063607617
#      total_time : 26.0
#      computing_time : 0.029783964157104492
#      -----------------------------------------------------------------------------------------------------------------------
#
# 57 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.75365399
#      phi = 1.924140537
#      selected_dt : 2.59
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      first_fidelity : 0.9910431523611134
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3]
#      last_fidelity : 0.9927292600981561
#      total_time : 72.52
#      computing_time : 998.0760598182678
#      -----------------------------------------------------------------------------------------------------------------------
#
# 58 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.459044929
#      phi = 0.170257132
#      selected_dt : 2.6
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 4, 4, 2, 3]
#      first_fidelity : 0.991302910776678
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 0, 2, 2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.9999072248139727
#      total_time : 49.4
#      computing_time : 278.521600484848
#      -----------------------------------------------------------------------------------------------------------------------
#
# 59 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 3.029522104
#      phi = 6.25055835
#      selected_dt : 2.61
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 2, 2]
#      first_fidelity : 0.9935480769827495
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2]
#      last_fidelity : 0.9978842988653855
#      total_time : 86.13
#      computing_time : 1005.4989733695984
#      -----------------------------------------------------------------------------------------------------------------------
#
# 60 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.04690955
#      phi = 3.59511117
#      selected_dt : 2.62
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 2]
#      first_fidelity : 0.9901794104551154
#      output_sequence : [3, 3, 2, 2, 4, 4, 4, 1, 1, 3, 3, 2]
#      last_fidelity : 0.9999571685135248
#      total_time : 31.44
#      computing_time : 982.1237909793854
#      -----------------------------------------------------------------------------------------------------------------------
#
# 61 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 1.9284660973534264
#      phi = 4.723903361433421
#      selected_dt : 2.6
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 3, 0, 1, 3, 2]
#      first_fidelity : 0.9998587207052609
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 3, 0, 3, 3, 3]
#      last_fidelity : 0.9999967986690284
#      total_time : 67.60000000000001
#      computing_time : 0.3307344913482666
#      -----------------------------------------------------------------------------------------------------------------------
#
# 62 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.511381419
#      phi = 3.784687136
#      selected_dt : 2.6
#      input_sequence : [3, 3, 2, 2]
#      first_fidelity : 0.9945192221734841
#      output_sequence : [3, 3, 2, 2]
#      last_fidelity : 0.9945192221734841
#      total_time : 10.4
#      computing_time : 2.4241561889648438
#      -----------------------------------------------------------------------------------------------------------------------
#
# 63 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.242930077
#      phi = 3.207399527
#      selected_dt : 3.1
#      input_sequence : [3, 2]
#      first_fidelity : 0.9991623160145021
#      output_sequence : [3, 2]
#      last_fidelity : 0.9998544292438813
#      total_time : 6.2
#      computing_time : 0.8825111389160156
#      -----------------------------------------------------------------------------------------------------------------------
#
# 64 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.785054479
#      phi = 3.349651362
#      selected_dt : 2.61
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 1, 1]
#      first_fidelity : 0.9955462445599534
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 4, 4, 1, 1, 3]
#      last_fidelity : 0.9997484613320876
#      total_time : 86.13
#      computing_time : 1004.7065947055817
#      -----------------------------------------------------------------------------------------------------------------------
#
# 65 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.94334562
#      phi = 4.52748003
#      selected_dt : 2.6
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 3]
#      first_fidelity : 0.9985442804334272
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 1, 3, 2, 2]
#      last_fidelity : 0.9999435730205186
#      total_time : 85.8
#      computing_time : 35.19059228897095
#      -----------------------------------------------------------------------------------------------------------------------
#
# 66 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.148119619
#      phi = 1.068118037
#      selected_dt : 2.61
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 0, 4, 4, 4]
#      first_fidelity : 0.9926488209258202
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 3, 2, 2, 4, 4, 4]
#      last_fidelity : 0.9989288566680616
#      total_time : 67.86
#      computing_time : 999.0852108001709
#      -----------------------------------------------------------------------------------------------------------------------
#
# 67 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 3.021338433
#      phi = 3.443343245
#      selected_dt : 2.61
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 3]
#      first_fidelity : 0.9946857729678905
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 1, 3]
#      last_fidelity : 0.9954079071816727
#      total_time : 83.52
#      computing_time : 1005.3187463283539
#      -----------------------------------------------------------------------------------------------------------------------
#
# 68 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.356391514
#      phi = 6.160805802
#      selected_dt : 2.6
#      input_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 1, 1]
#      first_fidelity : 0.996402672334605
#      output_sequence : [4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 0]
#      last_fidelity : 0.9999081726195688
#      total_time : 67.60000000000001
#      computing_time : 0.05402779579162598
#      -----------------------------------------------------------------------------------------------------------------------
#
# 69 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.495915388
#      phi = 5.143403006
#      selected_dt : 2.59
#      input_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      first_fidelity : 0.9919908423385295
#      output_sequence : [4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 1]
#      last_fidelity : 0.9935197175775744
#      total_time : 67.34
#      computing_time : 999.2600739002228
#      -----------------------------------------------------------------------------------------------------------------------
#
# 70 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.785460963
#      phi = 5.629100226
#      selected_dt : 2.62
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      first_fidelity : 0.9907054283071985
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4]
#      last_fidelity : 0.9945338540899501
#      total_time : 73.36
#      computing_time : 1003.757241487503
#      -----------------------------------------------------------------------------------------------------------------------
#
# 71 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.280746434
#      phi = 1.478929712
#      selected_dt : 3.05
#      input_sequence : [1, 1]
#      first_fidelity : 0.9918138947005711
#      output_sequence : [1, 3]
#      last_fidelity : 0.9984252486184617
#      total_time : 6.1
#      computing_time : 0.8941421508789062
#      -----------------------------------------------------------------------------------------------------------------------
#
# 72 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.6224133027731167
#      phi = 4.327703924469086
#      selected_dt : 2.6
#      input_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 0, 1, 0, 0, 3, 3]
#      first_fidelity : 0.996891598874727
#      output_sequence : [2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 2, 4, 1, 3, 3, 2]
#      last_fidelity : 0.9999804490420732
#      total_time : 85.8
#      computing_time : 26.596436738967896
#      -----------------------------------------------------------------------------------------------------------------------
#
# 73 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.802374974
#      phi = 1.412894938
#      selected_dt : 2.6
#      input_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 2, 0, 1]
#      first_fidelity : 0.9971495109948939
#      output_sequence : [1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 2, 2, 4, 1]
#      last_fidelity : 0.9999020686689228
#      total_time : 85.8
#      computing_time : 0.054028987884521484
#      -----------------------------------------------------------------------------------------------------------------------
#
# 74 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.502942846
#      phi = 3.464702591
#      selected_dt : 2.59
#      input_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2]
#      first_fidelity : 0.9922921322985425
#      output_sequence : [3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 4]
#      last_fidelity : 0.9974641109164205
#      total_time : 69.92999999999999
#      computing_time : 1005.2384884357452
#      -----------------------------------------------------------------------------------------------------------------------
#
# 75 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 0.58733795
#      phi = 1.769847136
#      selected_dt : 2.84
#      input_sequence : [4, 4, 1, 1, 3]
#      first_fidelity : 0.995497326821139
#      output_sequence : [4, 4, 1, 1, 3]
#      last_fidelity : 0.9982456788119882
#      total_time : 14.2
#      computing_time : 8.588180541992188
#      -----------------------------------------------------------------------------------------------------------------------
#
# 76 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.052549897
#      phi = 2.457714747
#      selected_dt : 2.6
#      input_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 3, 1, 4, 2]
#      first_fidelity : 0.990059083671627
#      output_sequence : [3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 4, 1, 4, 1]
#      last_fidelity : 0.9999198149373107
#      total_time : 67.60000000000001
#      computing_time : 1.513671636581421
#      -----------------------------------------------------------------------------------------------------------------------
#
# 77 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.62142983
#      phi = 0.644529781
#      selected_dt : 2.6
#      input_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      first_fidelity : 0.9911292103718464
#      output_sequence : [1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1]
#      last_fidelity : 0.9911292103718464
#      total_time : 67.60000000000001
#      computing_time : 1003.8395285606384
#      -----------------------------------------------------------------------------------------------------------------------
#
# 78 / 27806
#
#      -----------------------------------------------------------------------------------------------------------------------
#      theta = 2.292376033
#      phi = 3.594012025
#      selected_dt : 2.6
#      input_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 4, 2]
#      first_fidelity : 0.9937225550973887
#      output_sequence : [2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 4, 1, 1, 3, 2, 2, 4]
#      last_fidelity : 0.999699183119678
#      total_time : 67.60000000000001
#      computing_time : 1004.2664458751678
#      -----------------------------------------------------------------------------------------------------------------------
#
# 79 / 27806
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\Yeojung\ml\Quantum_2023\Local_Optimizer\temp2_dt.ipynb Cell 7 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/Yeojung/ml/Quantum_2023/Local_Optimizer/temp2_dt.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> target_U = Rz(input_phi) @ Rx(input_theta)
#       <a href='vscode-notebook-cell:/c%3A/Users/Yeojung/ml/Quantum_2023/Local_Optimizer/temp2_dt.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> input_rho = target_U @ irho_init @ target_U.conj().T
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Yeojung/ml/Quantum_2023/Local_Optimizer/temp2_dt.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> output_dt, output_sequence, first_fidelity, last_fidelity, total_time, computing_time = local_optimizer(input_rho, eval(input_sequence))
#      <a href='vscode-notebook-cell:/c%3A/Users/Yeojung/ml/Quantum_2023/Local_Optimizer/temp2_dt.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a> case += 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Yeojung/ml/Quantum_2023/Local_Optimizer/temp2_dt.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a> output = [['case' + str(case), len(output_sequence), input_theta, input_phi, output_dt, output_sequence,
#      <a href='vscode-notebook-cell:/c%3A/Users/Yeojung/ml/Quantum_2023/Local_Optimizer/temp2_dt.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>                last_fidelity, total_time, computing_time]]
#
# c:\Users\Yeojung\ml\Quantum_2023\Local_Optimizer\temp2_dt.ipynb Cell 7 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Yeojung/ml/Quantum_2023/Local_Optimizer/temp2_dt.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a> last_fid = fidelity(input_rho, output_dt, output_seq)
#      <a href='vscode-notebook-cell:/c%3A/Users/Yeojung/ml/Quantum_2023/Local_Optimizer/temp2_dt.ipynb#W6sZmlsZQ%3D%3D?line=21'>22</a> total_t = output_dt * len(output_seq)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Yeojung/ml/Quantum_2023/Local_Optimizer/temp2_dt.ipynb#W6sZmlsZQ%3D%3D?line=23'>24</a> return output_dt, output_seq, first_fid, last_fid, total_t, computing_t
#
# UnboundLocalError: local variable 'computing_t' referenced before assignment
